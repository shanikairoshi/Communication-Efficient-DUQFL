# %% [markdown]
# <a href="https://colab.research.google.com/github/shanikairoshi/Communication-Efficient-DUQFL/blob/main/main_mnist_0.12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install genomic-benchmarks
# !pip install qiskit qiskit_machine_learning qiskit_algorithms qiskit-aer
# Out:
# Collecting genomic-benchmarks
#   Downloading genomic_benchmarks-1.0.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting biopython>=1.79 (from genomic-benchmarks)
#   Downloading biopython-1.85-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (2.32.4)
# Requirement already satisfied: pip>=20.0.1 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (24.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (2.0.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (4.67.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (6.0.3)
# Requirement already satisfied: gdown>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (5.2.0)
# Requirement already satisfied: yarl in /usr/local/lib/python3.12/dist-packages (from genomic-benchmarks) (1.22.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.2.0->genomic-benchmarks) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=4.2.0->genomic-benchmarks) (3.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->genomic-benchmarks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->genomic-benchmarks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->genomic-benchmarks) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->genomic-benchmarks) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->genomic-benchmarks) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->genomic-benchmarks) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->genomic-benchmarks) (2025.10.5)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.12/dist-packages (from yarl->genomic-benchmarks) (6.7.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from yarl->genomic-benchmarks) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.4->genomic-benchmarks) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.2.0->genomic-benchmarks) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.2.0->genomic-benchmarks) (4.15.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.2.0->genomic-benchmarks) (1.7.1)
# Downloading biopython-1.85-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.0 MB/s eta 0:00:00
# Building wheels for collected packages: genomic-benchmarks
#   Building wheel for genomic-benchmarks (setup.py) ... done
#   Created wheel for genomic-benchmarks: filename=genomic_benchmarks-1.0.0-py3-none-any.whl size=22550 sha256=037f1cc7fcb91ed4b46c0fdbe8905597881df9a8946e7e4af469342e1ebd08de
#   Stored in directory: /root/.cache/pip/wheels/9a/3a/9a/0f21797a390f81beeeb52e9ccc71e6d5e262786ecd01e046bf
# Successfully built genomic-benchmarks
# Installing collected packages: biopython, genomic-benchmarks
# Successfully installed biopython-1.85 genomic-benchmarks-1.0.0
# Collecting qiskit
#   Downloading qiskit-2.2.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting qiskit_machine_learning
#   Downloading qiskit_machine_learning-0.8.4-py3-none-any.whl.metadata (13 kB)
# Collecting qiskit_algorithms
#   Downloading qiskit_algorithms-0.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.2)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Collecting qiskit
#   Downloading qiskit-1.4.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting scipy>=1.5 (from qiskit)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.12/dist-packages (from qiskit_machine_learning) (1.6.1)
# Requirement already satisfied: setuptools>=40.1 in /usr/local/lib/python3.12/dist-packages (from qiskit_machine_learning) (75.2.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.13.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.9.0.post0)
# Collecting symengine<0.14,>=0.11 (from qiskit)
#   Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->qiskit_machine_learning) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->qiskit_machine_learning) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit) (1.3.0)
# Downloading qiskit_machine_learning-0.8.4-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 7.8 MB/s eta 0:00:00
# Downloading qiskit-1.4.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 78.6 MB/s eta 0:00:00
# Downloading qiskit_algorithms-0.4.0-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 23.9 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 92.6 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 82.3 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 59.9 MB/s eta 0:00:00
# Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.2 MB/s eta 0:00:00
# Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 37.5 MB/s eta 0:00:00
# Installing collected packages: symengine, stevedore, scipy, rustworkx, qiskit, qiskit_machine_learning, qiskit_algorithms, qiskit-aer
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
# Successfully installed qiskit-1.4.5 qiskit-aer-0.17.2 qiskit_algorithms-0.4.0 qiskit_machine_learning-0.8.4 rustworkx-0.17.1 scipy-1.15.3 stevedore-5.5.0 symengine-0.13.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path
PROJ = Path.cwd() / "tduqfl_mnist"
if str(PROJ) not in sys.path:
    sys.path.insert(0, str(PROJ))
import sys
sys.path.append('/content/drive/MyDrive/Teleportation/tduqfl_mnist/tDuQFL_Project')
# ─── 5. Assemble filenames for each artifact ─────────────────────────────────
drive_root = "/content/drive/MyDrive/Teleportation/tduqfl_mnist/tDuQFL_Project/"

# %%
#from configs.dataset_genome_noniid.py import *     # swap to other configs as needed

# %%
from common.imports import *
from configs.dataset_genome import *     # swap to other configs as needed
from io_utils.naming import stamp_now, build_param_str, make_filenames

# main.py or notebook cell
from configs.base_config import *
from io_utils.naming import build_param_str, stamp_now, make_filenames

param_str = build_param_str(
    num_clients,
    num_federated_layers,
    num_deep_unfolding_iterations,
    initial_learning_rate,
    initial_perturbation,
)
stamp, date_str = stamp_now()

best_client_csv_file, global_csv_file, local_csv_file, validation_csv_file = make_filenames(
    drive_root=drive_root,
    dataset_name=dataset_name,
    split_type=split_type,
    date_str=date_str,
    aggregation=aggregation,
    select_upload=select_upload,
    use_deep_unfolding=use_deep_unfolding,
    gamma=gamma,
    uplink_mode=uplink_mode,
    downlink_mode=downlink_mode,
    up_k_ratio=up_k_ratio,
    up_bits=up_bits,
    down_mask_ratio=down_mask_ratio,
    down_scale=down_scale,
    noise_preset=noise_preset,
    shots_used=shots_used,
    param_str=param_str,
)
print(best_client_csv_file)
print(global_csv_file)
print(local_csv_file)
print(validation_csv_file)


from io_utils.csv_logger import init_local_csv, init_best_csv, init_validation_csv

# Create folders + write headers
init_best_csv(best_client_csv_file)

local_headers = [
    "Federated Round", "Client Number", "Iteration",
    "Objective Function Value", "Training Accuracy", "Test Accuracy",
    "Learning Rate", "Perturbation"
]
init_local_csv(local_csv_file, local_headers)

init_validation_csv(validation_csv_file)

# Do NOT pre-init global_csv_file here because your save_accuracies_to_csv()
# already writes the header each time it runs (in 'w' mode).
# Out:
# /usr/local/lib/python3.12/dist-packages/genomic_benchmarks/utils/datasets.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Qiskit: 1.4.5
# qiskit_aer available?: True
# /content/drive/MyDrive/Teleportation/tduqfl_mnist/result/best_all/tDuQFL_MNIST_NONIID_AGG-best_SU-all_DU-on_g0p5_UL-quantum__DL-quantum_Q-on_med_shots256_params[clients5_layers10_du5_lr0p12_pert0p12]_19_10_2025_Best_Client.csv
# /content/drive/MyDrive/Teleportation/tduqfl_mnist/result/best_all/tDuQFL_MNIST_NONIID_AGG-best_SU-all_DU-on_g0p5_UL-quantum__DL-quantum_Q-on_med_shots256_params[clients5_layers10_du5_lr0p12_pert0p12]_19_10_2025_Global.csv
# /content/drive/MyDrive/Teleportation/tduqfl_mnist/result/best_all/tDuQFL_MNIST_NONIID_AGG-best_SU-all_DU-on_g0p5_UL-quantum__DL-quantum_Q-on_med_shots256_params[clients5_layers10_du5_lr0p12_pert0p12]_19_10_2025_Local.csv
# /content/drive/MyDrive/Teleportation/tduqfl_mnist/result/best_all/tDuQFL_MNIST_NONIID_AGG-best_SU-all_DU-on_g0p5_UL-quantum__DL-quantum_Q-on_med_shots256_params[clients5_layers10_du5_lr0p12_pert0p12]_19_10_2025_Validation_Loss.csv

# %% [markdown]
# Load and Split data

# %%
from training.loop import run_federated_training
from configs.base_config import use_teleportation as CFG_TEL, noise_preset, shots_used
from training.metrics import metrics_init, metrics_log_round, metrics_finalize, compute_auc,metrics_summarize
from viz.plots import plot_accuracy_curve, plot_val_loss, plot_time_per_round, plot_fidelity_vs_delta_acc, plot_beta_hist, plot_client_fairness_last_round
# Initialize metrics store once
metrics_store = metrics_init(
    log_path=os.path.join(drive_root, "teleport_metrics_Perturb_shrink.csv")
)

#new
from ml import optimizers as mlopt
from configs.base_config import drive_root
import os

mlopt.meta_trace_enable(
    path=os.path.join(drive_root, "meta_trace.csv"),  # or None to skip CSV
    every=5                                           # print every 5 callbacks
)

# examples/run_switch.py
from configs.base_config import *
from training.data_factory import build_clients_and_meta
from training.loop import run_federated_training
from training.metrics import metrics_init
import os, numpy as np

param_str = build_param_str(
    num_clients,
    num_federated_layers,
    num_deep_unfolding_iterations,
    initial_learning_rate,
    initial_perturbation,
)


# 1) Build clients + meta from config
clients, test_sequences, test_labels, num_features = build_clients_and_meta(
    dataset_name=dataset_name,
    split_type=split_type,
    num_clients=num_clients,
    num_epochs=num_epochs,
    samples_per_epoch=samples_per_epoch,
    word_size=word_size,
    global_seed=global_seed,
    mnist_n_features=mnist_n_features,
    mnist_digit_a=mnist_digit_a,
    mnist_digit_b=mnist_digit_b,
    breast_pca_n_features=breast_pca_n_features,
    non_iid_ratio=non_iid_ratio,
    quantity_variation=quantity_variation,
    noniid_seed=noniid_seed,
)

# 2) Validation set (use test as val if you don’t have a separate split)
X_val, y_val = test_sequences, test_labels

# 3) Outputs
os.makedirs(drive_root, exist_ok=True)


metrics = metrics_init(log_path=os.path.join(drive_root, "round_metrics.csv"))

# 4) Train
global_acc, clients_train, clients_test, round_times, val_losses, info_last = run_federated_training(
    clients=clients,
    num_federated_layers=num_federated_layers,
    num_deep_unfolding_iterations=num_deep_unfolding_iterations,
    initial_learning_rate=initial_learning_rate,
    initial_perturbation=initial_perturbation,
    num_features=num_features,
    best_client_csv_file=best_client_csv_file,
    global_csv_file=global_csv_file,
    local_csv_file=local_csv_file,
    validation_csv_file=validation_csv_file,
    test_sequences=test_sequences, test_labels=test_labels,
    X_val=X_val,
    y_val=y_val,
    metrics=metrics,
    aggregation=aggregation,                  # "best" or "fedavg"
    select_upload=select_upload,              # "all" or "winner_only" (used for best)
    use_deep_unfolding=use_deep_unfolding,    # True/False
    uplink_mode=uplink_mode,                  # "classical_full" | "seeded_sparse" | "quantum"
    downlink_mode=downlink_mode,              # "classical_full" | "seeded" | "quantum"
    down_seed_base=down_seed_base,
    down_scale=down_scale,
    down_mask_ratio=down_mask_ratio,
    up_bits=up_bits,
    up_k_ratio=up_k_ratio,
    use_teleportation_backend=True,
    noise_preset=noise_preset,
    shots_used=shots_used,
    client_hparams_csv_file=os.path.join(drive_root, f"hparams_{dataset_name}_{split_type}.csv"),
)

print("Global accuracy per round:", global_acc)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 6.81MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 160kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.52MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.58MB/s]
# Training Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# [Round 0] Agg=best | Uplink=quantum | Downlink=quantum
# [meta] cb#005 loss=1.328878 step=0.6382 g_raw=+0.313 g_sm=+0.075 acc=1 | LR→0.120241 PERT→0.120001 (scale=0.04)
# [meta] cb#010 loss=1.211599 step=0.00846 g_raw=+0.003 g_sm=+0.071 acc=1 | LR→0.120484 PERT→0.120003 (scale=0.04)
# [meta] cb#015 loss=1.135070 step=0.1017 g_raw=+0.054 g_sm=+0.074 acc=1 | LR→0.120727 PERT→0.120005 (scale=0.04)
# [meta] cb#020 loss=1.010904 step=0.1119 g_raw=+0.052 g_sm=+0.079 acc=1 | LR→0.120970 PERT→0.120007 (scale=0.04)
# [meta] cb#025 loss=0.944604 step=0.08184 g_raw=+0.049 g_sm=+0.074 acc=1 | LR→0.121215 PERT→0.120008 (scale=0.04)
# [client 0 | unfold 1] LR 0.120000->0.121215, PERT 0.120000->0.120008 | g_raw_mean=+0.126, g_sm_mean=+0.070
# [meta] cb#030 loss=0.914701 step=0.07976 g_raw=+0.036 g_sm=+0.068 acc=1 | LR→0.121459 PERT→0.120010 (scale=0.04)
# [meta] cb#035 loss=0.899431 step=0.118 g_raw=+0.068 g_sm=+0.061 acc=1 | LR→0.121704 PERT→0.120012 (scale=0.04)
# [meta] cb#040 loss=0.889318 step=0.04055 g_raw=+0.021 g_sm=+0.053 acc=1 | LR→0.121949 PERT→0.120013 (scale=0.04)
# [meta] cb#045 loss=0.873624 step=0.09893 g_raw=+0.045 g_sm=+0.049 acc=1 | LR→0.122194 PERT→0.120014 (scale=0.04)
# [meta] cb#050 loss=0.868619 step=0.02935 g_raw=+0.007 g_sm=+0.043 acc=1 | LR→0.122440 PERT→0.120015 (scale=0.04)
# [client 0 | unfold 2] LR 0.121215->0.122440, PERT 0.120008->0.120015 | g_raw_mean=+0.033, g_sm_mean=+0.057
# [meta] cb#055 loss=0.866649 step=0.04332 g_raw=+0.026 g_sm=+0.036 acc=1 | LR→0.122686 PERT→0.120016 (scale=0.04)
# [meta] cb#060 loss=0.865396 step=0.006651 g_raw=+0.004 g_sm=+0.029 acc=1 | LR→0.122932 PERT→0.120017 (scale=0.04)
# [meta] cb#065 loss=0.864747 step=0.02981 g_raw=+0.015 g_sm=+0.024 acc=1 | LR→0.123179 PERT→0.120018 (scale=0.04)
# [meta] cb#070 loss=0.863121 step=0.02046 g_raw=+0.008 g_sm=+0.021 acc=1 | LR→0.123426 PERT→0.120018 (scale=0.04)
# [meta] cb#075 loss=0.862960 step=0.005443 g_raw=+0.003 g_sm=+0.017 acc=1 | LR→0.123674 PERT→0.120019 (scale=0.04)
# [client 0 | unfold 3] LR 0.122440->0.123674, PERT 0.120015->0.120019 | g_raw_mean=+0.008, g_sm_mean=+0.027
# [meta] cb#080 loss=0.862533 step=0.01266 g_raw=+0.010 g_sm=+0.015 acc=1 | LR→0.123922 PERT→0.120019 (scale=0.04)
# [meta] cb#085 loss=0.862492 step=0.005418 g_raw=+0.003 g_sm=+0.012 acc=1 | LR→0.124170 PERT→0.120019 (scale=0.04)
# [meta] cb#090 loss=0.862286 step=0.01909 g_raw=+0.008 g_sm=+0.010 acc=1 | LR→0.124419 PERT→0.120020 (scale=0.04)
# [meta] cb#095 loss=0.862143 step=0.002175 g_raw=-0.002 g_sm=+0.008 acc=1 | LR→0.124668 PERT→0.120020 (scale=0.04)
# [meta] cb#100 loss=0.862139 step=0.009349 g_raw=-0.001 g_sm=+0.006 acc=1 | LR→0.124918 PERT→0.120020 (scale=0.04)
# [client 0 | unfold 4] LR 0.123674->0.124918, PERT 0.120019->0.120020 | g_raw_mean=+0.003, g_sm_mean=+0.011
# [meta] cb#105 loss=0.862007 step=5.986e-05 g_raw=+0.004 g_sm=+0.006 acc=1 | LR→0.125168 PERT→0.120020 (scale=0.04)
# [meta] cb#110 loss=0.861928 step=0.01334 g_raw=+0.005 g_sm=+0.005 acc=1 | LR→0.125419 PERT→0.120020 (scale=0.04)
# [meta] cb#115 loss=0.861854 step=0.007006 g_raw=+0.002 g_sm=+0.004 acc=1 | LR→0.125670 PERT→0.120020 (scale=0.04)
# [meta] cb#120 loss=0.861790 step=0.001019 g_raw=-0.001 g_sm=+0.003 acc=1 | LR→0.125922 PERT→0.120020 (scale=0.04)
# [meta] cb#125 loss=0.861694 step=0.000704 g_raw=-0.001 g_sm=+0.003 acc=1 | LR→0.126174 PERT→0.120020 (scale=0.04)
# [client 0 | unfold 5] LR 0.124918->0.126174, PERT 0.120020->0.120020 | g_raw_mean=+0.002, g_sm_mean=+0.004
# [meta] cb#005 loss=1.202408 step=0.1552 g_raw=+0.104 g_sm=+0.048 acc=1 | LR→0.120241 PERT→0.120001 (scale=0.04)
# [meta] cb#010 loss=1.104545 step=0.009596 g_raw=-0.004 g_sm=+0.055 acc=1 | LR→0.120483 PERT→0.120002 (scale=0.04)
# [meta] cb#015 loss=1.026480 step=0.04889 g_raw=+0.030 g_sm=+0.059 acc=1 | LR→0.120726 PERT→0.120004 (scale=0.04)
# [meta] cb#020 loss=0.820500 step=0.316 g_raw=+0.179 g_sm=+0.079 acc=1 | LR→0.120969 PERT→0.120005 (scale=0.04)
# [meta] cb#025 loss=0.689116 step=0.1239 g_raw=+0.051 g_sm=+0.084 acc=1 | LR→0.121213 PERT→0.120007 (scale=0.04)
# [client 1 | unfold 1] LR 0.120000->0.121213, PERT 0.120000->0.120007 | g_raw_mean=+0.123, g_sm_mean=+0.059
# [meta] cb#030 loss=0.606766 step=0.02158 g_raw=+0.006 g_sm=+0.082 acc=1 | LR→0.121458 PERT→0.120009 (scale=0.04)
# [meta] cb#035 loss=0.580614 step=0.08179 g_raw=+0.036 g_sm=+0.073 acc=1 | LR→0.121703 PERT→0.120011 (scale=0.04)
# [meta] cb#040 loss=0.543386 step=0.002477 g_raw=+0.005 g_sm=+0.068 acc=1 | LR→0.121948 PERT→0.120013 (scale=0.04)
# [meta] cb#045 loss=0.530607 step=0.09013 g_raw=+0.040 g_sm=+0.060 acc=1 | LR→0.122194 PERT→0.120014 (scale=0.04)
# [meta] cb#050 loss=0.524059 step=0.02474 g_raw=+0.012 g_sm=+0.051 acc=1 | LR→0.122440 PERT→0.120016 (scale=0.04)
# [client 1 | unfold 2] LR 0.121213->0.122440, PERT 0.120007->0.120016 | g_raw_mean=+0.046, g_sm_mean=+0.070
# [meta] cb#055 loss=0.515106 step=0.03561 g_raw=+0.019 g_sm=+0.045 acc=1 | LR→0.122686 PERT→0.120017 (scale=0.04)
# [meta] cb#060 loss=0.504839 step=0.01223 g_raw=+0.006 g_sm=+0.041 acc=1 | LR→0.122933 PERT→0.120018 (scale=0.04)
# [meta] cb#065 loss=0.503756 step=0.002389 g_raw=-0.001 g_sm=+0.033 acc=1 | LR→0.123180 PERT→0.120019 (scale=0.04)
# [meta] cb#070 loss=0.497435 step=0.05963 g_raw=+0.020 g_sm=+0.030 acc=1 | LR→0.123427 PERT→0.120019 (scale=0.04)
# [meta] cb#075 loss=0.494155 step=0.006057 g_raw=+0.007 g_sm=+0.026 acc=1 | LR→0.123675 PERT→0.120020 (scale=0.04)
# [client 1 | unfold 3] LR 0.122440->0.123675, PERT 0.120016->0.120020 | g_raw_mean=+0.018, g_sm_mean=+0.037
# [meta] cb#080 loss=0.490888 step=0.01909 g_raw=+0.010 g_sm=+0.024 acc=1 | LR→0.123923 PERT→0.120021 (scale=0.04)
# [meta] cb#085 loss=0.490491 step=0.002208 g_raw=+0.003 g_sm=+0.019 acc=1 | LR→0.124172 PERT→0.120021 (scale=0.04)
# [meta] cb#090 loss=0.488527 step=0.0289 g_raw=+0.012 g_sm=+0.018 acc=1 | LR→0.124421 PERT→0.120022 (scale=0.04)
# [meta] cb#095 loss=0.488074 step=0.02065 g_raw=+0.000 g_sm=+0.015 acc=1 | LR→0.124671 PERT→0.120022 (scale=0.04)
# [meta] cb#100 loss=0.487753 step=0.00881 g_raw=+0.001 g_sm=+0.012 acc=1 | LR→0.124920 PERT→0.120022 (scale=0.04)
# [client 1 | unfold 4] LR 0.123675->0.124920, PERT 0.120020->0.120022 | g_raw_mean=+0.008, g_sm_mean=+0.019
# [meta] cb#105 loss=0.487321 step=0.02286 g_raw=+0.005 g_sm=+0.011 acc=1 | LR→0.125171 PERT→0.120023 (scale=0.04)
# [meta] cb#110 loss=0.487263 step=0.01105 g_raw=-0.001 g_sm=+0.008 acc=1 | LR→0.125422 PERT→0.120023 (scale=0.04)
# [meta] cb#115 loss=0.486362 step=0.02934 g_raw=+0.014 g_sm=+0.008 acc=1 | LR→0.125673 PERT→0.120023 (scale=0.04)
# [meta] cb#120 loss=0.485927 step=0.005438 g_raw=+0.003 g_sm=+0.008 acc=1 | LR→0.125925 PERT→0.120023 (scale=0.04)
# [meta] cb#125 loss=0.485646 step=0.02487 g_raw=+0.001 g_sm=+0.006 acc=1 | LR→0.126177 PERT→0.120023 (scale=0.04)
# [client 1 | unfold 5] LR 0.124920->0.126177, PERT 0.120022->0.120023 | g_raw_mean=+0.004, g_sm_mean=+0.009
# [meta] cb#005 loss=2.578875 step=0.1447 g_raw=+0.074 g_sm=+0.034 acc=1 | LR→0.120241 PERT→0.120000 (scale=0.04)
# [meta] cb#010 loss=2.078504 step=0.1478 g_raw=+0.107 g_sm=+0.067 acc=1 | LR→0.120483 PERT→0.120002 (scale=0.04)
# [meta] cb#015 loss=1.753202 step=0.2878 g_raw=+0.178 g_sm=+0.090 acc=1 | LR→0.120726 PERT→0.120004 (scale=0.04)
# [meta] cb#020 loss=1.422135 step=0.1904 g_raw=+0.148 g_sm=+0.105 acc=1 | LR→0.120970 PERT→0.120006 (scale=0.04)
# [meta] cb#025 loss=1.106702 step=0.3968 g_raw=+0.231 g_sm=+0.116 acc=1 | LR→0.121215 PERT→0.120009 (scale=0.04)
# [client 2 | unfold 1] LR 0.120000->0.121215, PERT 0.120000->0.120009 | g_raw_mean=+0.161, g_sm_mean=+0.073
# [meta] cb#030 loss=1.049731 step=0.03679 g_raw=+0.030 g_sm=+0.104 acc=1 | LR→0.121460 PERT→0.120011 (scale=0.04)
# [meta] cb#035 loss=1.003151 step=0.1566 g_raw=+0.090 g_sm=+0.094 acc=1 | LR→0.121706 PERT→0.120014 (scale=0.04)
# [meta] cb#040 loss=0.984238 step=0.07285 g_raw=+0.041 g_sm=+0.083 acc=1 | LR→0.121951 PERT→0.120016 (scale=0.04)
# [meta] cb#045 loss=0.873881 step=0.04104 g_raw=+0.021 g_sm=+0.080 acc=1 | LR→0.122198 PERT→0.120018 (scale=0.04)
# [meta] cb#050 loss=0.837833 step=0.04498 g_raw=+0.025 g_sm=+0.074 acc=1 | LR→0.122444 PERT→0.120020 (scale=0.04)
# [client 2 | unfold 2] LR 0.121215->0.122444, PERT 0.120009->0.120020 | g_raw_mean=+0.058, g_sm_mean=+0.090
# [meta] cb#055 loss=0.798387 step=0.2028 g_raw=+0.104 g_sm=+0.071 acc=1 | LR→0.122691 PERT→0.120021 (scale=0.04)
# [meta] cb#060 loss=0.764123 step=0.04266 g_raw=+0.019 g_sm=+0.067 acc=1 | LR→0.122938 PERT→0.120023 (scale=0.04)
# [meta] cb#065 loss=0.742578 step=0.09171 g_raw=+0.050 g_sm=+0.062 acc=1 | LR→0.123186 PERT→0.120024 (scale=0.04)
# [meta] cb#070 loss=0.703080 step=0.2073 g_raw=+0.106 g_sm=+0.062 acc=1 | LR→0.123434 PERT→0.120026 (scale=0.04)
# [meta] cb#075 loss=0.684410 step=0.008485 g_raw=+0.004 g_sm=+0.055 acc=1 | LR→0.123683 PERT→0.120027 (scale=0.04)
# [client 2 | unfold 3] LR 0.122444->0.123683, PERT 0.120020->0.120027 | g_raw_mean=+0.050, g_sm_mean=+0.064
# [meta] cb#080 loss=0.677794 step=0.0345 g_raw=+0.013 g_sm=+0.049 acc=1 | LR→0.123932 PERT→0.120028 (scale=0.04)
# [meta] cb#085 loss=0.663314 step=0.004357 g_raw=+0.005 g_sm=+0.045 acc=1 | LR→0.124181 PERT→0.120030 (scale=0.04)
# [meta] cb#090 loss=0.654668 step=0.007556 g_raw=+0.001 g_sm=+0.040 acc=1 | LR→0.124430 PERT→0.120031 (scale=0.04)
# [meta] cb#095 loss=0.646338 step=0.04475 g_raw=+0.023 g_sm=+0.037 acc=1 | LR→0.124681 PERT→0.120032 (scale=0.04)
# [meta] cb#100 loss=0.643728 step=0.0007718 g_raw=+0.001 g_sm=+0.031 acc=1 | LR→0.124931 PERT→0.120032 (scale=0.04)
# [client 2 | unfold 4] LR 0.123683->0.124931, PERT 0.120027->0.120032 | g_raw_mean=+0.024, g_sm_mean=+0.043
# [meta] cb#105 loss=0.640870 step=0.004791 g_raw=+0.005 g_sm=+0.027 acc=1 | LR→0.125182 PERT→0.120033 (scale=0.04)
# [meta] cb#110 loss=0.639842 step=0.01697 g_raw=+0.004 g_sm=+0.023 acc=1 | LR→0.125433 PERT→0.120034 (scale=0.04)
# [meta] cb#115 loss=0.638266 step=0.04497 g_raw=+0.022 g_sm=+0.020 acc=1 | LR→0.125685 PERT→0.120034 (scale=0.04)
# [meta] cb#120 loss=0.637746 step=0.02749 g_raw=+0.007 g_sm=+0.016 acc=1 | LR→0.125937 PERT→0.120035 (scale=0.04)
# [meta] cb#125 loss=0.637063 step=0.01258 g_raw=+0.005 g_sm=+0.014 acc=1 | LR→0.126189 PERT→0.120035 (scale=0.04)
# [client 2 | unfold 5] LR 0.124931->0.126189, PERT 0.120032->0.120035 | g_raw_mean=+0.009, g_sm_mean=+0.021
# [meta] cb#005 loss=1.272829 step=0.5655 g_raw=+0.263 g_sm=+0.045 acc=1 | LR→0.120241 PERT→0.120001 (scale=0.04)
# [meta] cb#010 loss=1.150382 step=0.1084 g_raw=+0.051 g_sm=+0.055 acc=1 | LR→0.120483 PERT→0.120002 (scale=0.04)
# [meta] cb#015 loss=1.026307 step=0.2025 g_raw=+0.127 g_sm=+0.066 acc=1 | LR→0.120725 PERT→0.120003 (scale=0.04)
# [meta] cb#020 loss=0.989420 step=0.07054 g_raw=+0.019 g_sm=+0.062 acc=1 | LR→0.120969 PERT→0.120005 (scale=0.04)
# [meta] cb#025 loss=0.850951 step=0.2688 g_raw=+0.165 g_sm=+0.074 acc=1 | LR→0.121212 PERT→0.120006 (scale=0.04)
# [client 3 | unfold 1] LR 0.120000->0.121212, PERT 0.120000->0.120006 | g_raw_mean=+0.109, g_sm_mean=+0.053
# [meta] cb#030 loss=0.720772 step=0.0902 g_raw=+0.052 g_sm=+0.079 acc=1 | LR→0.121457 PERT→0.120008 (scale=0.04)
# [meta] cb#035 loss=0.662532 step=0.05247 g_raw=+0.018 g_sm=+0.077 acc=1 | LR→0.121702 PERT→0.120010 (scale=0.04)
# [meta] cb#040 loss=0.552559 step=0.2957 g_raw=+0.099 g_sm=+0.080 acc=1 | LR→0.121948 PERT→0.120012 (scale=0.04)
# [meta] cb#045 loss=0.467681 step=0.2318 g_raw=+0.126 g_sm=+0.077 acc=1 | LR→0.122194 PERT→0.120014 (scale=0.04)
# [meta] cb#050 loss=0.428292 step=0.02621 g_raw=+0.009 g_sm=+0.070 acc=1 | LR→0.122440 PERT→0.120016 (scale=0.04)
# [client 3 | unfold 2] LR 0.121212->0.122440, PERT 0.120006->0.120016 | g_raw_mean=+0.074, g_sm_mean=+0.077
# [meta] cb#055 loss=0.417892 step=0.03176 g_raw=+0.017 g_sm=+0.060 acc=1 | LR→0.122687 PERT→0.120017 (scale=0.04)
# [meta] cb#060 loss=0.410914 step=0.05078 g_raw=+0.020 g_sm=+0.052 acc=1 | LR→0.122934 PERT→0.120019 (scale=0.04)
# [meta] cb#065 loss=0.401606 step=0.04057 g_raw=+0.013 g_sm=+0.045 acc=1 | LR→0.123181 PERT→0.120020 (scale=0.04)
# [meta] cb#070 loss=0.401132 step=0.02652 g_raw=+0.008 g_sm=+0.036 acc=1 | LR→0.123429 PERT→0.120021 (scale=0.04)
# [meta] cb#075 loss=0.398918 step=0.03077 g_raw=+0.008 g_sm=+0.031 acc=1 | LR→0.123677 PERT→0.120021 (scale=0.04)
# [client 3 | unfold 3] LR 0.122440->0.123677, PERT 0.120016->0.120021 | g_raw_mean=+0.019, g_sm_mean=+0.048
# [meta] cb#080 loss=0.397355 step=0.008931 g_raw=+0.001 g_sm=+0.026 acc=1 | LR→0.123925 PERT→0.120022 (scale=0.04)
# [meta] cb#085 loss=0.396119 step=0.0287 g_raw=+0.008 g_sm=+0.022 acc=1 | LR→0.124174 PERT→0.120023 (scale=0.04)
# [meta] cb#090 loss=0.394815 step=0.04225 g_raw=+0.014 g_sm=+0.019 acc=1 | LR→0.124423 PERT→0.120023 (scale=0.04)
# [meta] cb#095 loss=0.393724 step=0.002572 g_raw=+0.008 g_sm=+0.017 acc=1 | LR→0.124672 PERT→0.120024 (scale=0.04)
# [meta] cb#100 loss=0.392703 step=0.0177 g_raw=+0.001 g_sm=+0.015 acc=1 | LR→0.124922 PERT→0.120024 (scale=0.04)
# [client 3 | unfold 4] LR 0.123677->0.124922, PERT 0.120021->0.120024 | g_raw_mean=+0.009, g_sm_mean=+0.021
# [meta] cb#105 loss=0.392067 step=0.0006247 g_raw=+0.001 g_sm=+0.012 acc=1 | LR→0.125173 PERT→0.120024 (scale=0.04)
# [meta] cb#110 loss=0.391589 step=0.00854 g_raw=+0.002 g_sm=+0.011 acc=1 | LR→0.125424 PERT→0.120025 (scale=0.04)
# [meta] cb#115 loss=0.390629 step=0.01069 g_raw=+0.005 g_sm=+0.010 acc=1 | LR→0.125675 PERT→0.120025 (scale=0.04)
# [meta] cb#120 loss=0.389931 step=0.01221 g_raw=+0.006 g_sm=+0.009 acc=1 | LR→0.125927 PERT→0.120025 (scale=0.04)
# [meta] cb#125 loss=0.389379 step=0.002978 g_raw=+0.000 g_sm=+0.008 acc=1 | LR→0.126179 PERT→0.120025 (scale=0.04)
# [client 3 | unfold 5] LR 0.124922->0.126179, PERT 0.120024->0.120025 | g_raw_mean=+0.006, g_sm_mean=+0.011
# [meta] cb#005 loss=1.494082 step=0.2405 g_raw=+0.149 g_sm=+0.047 acc=1 | LR→0.120241 PERT→0.120001 (scale=0.04)
# [meta] cb#010 loss=1.422384 step=0.1932 g_raw=+0.120 g_sm=+0.054 acc=1 | LR→0.120483 PERT→0.120002 (scale=0.04)
# [meta] cb#015 loss=1.268028 step=0.2907 g_raw=+0.150 g_sm=+0.066 acc=1 | LR→0.120725 PERT→0.120003 (scale=0.04)
# [meta] cb#020 loss=1.170979 step=0.3044 g_raw=+0.152 g_sm=+0.072 acc=1 | LR→0.120969 PERT→0.120005 (scale=0.04)
# [meta] cb#025 loss=1.042832 step=0.1834 g_raw=+0.117 g_sm=+0.079 acc=1 | LR→0.121213 PERT→0.120007 (scale=0.04)
# [client 4 | unfold 1] LR 0.120000->0.121213, PERT 0.120000->0.120007 | g_raw_mean=+0.116, g_sm_mean=+0.056
# [meta] cb#030 loss=1.015493 step=0.1096 g_raw=+0.061 g_sm=+0.071 acc=1 | LR→0.121457 PERT→0.120008 (scale=0.04)
# [meta] cb#035 loss=0.928903 step=0.0544 g_raw=+0.030 g_sm=+0.072 acc=1 | LR→0.121702 PERT→0.120010 (scale=0.04)
# [meta] cb#040 loss=0.881163 step=0.07025 g_raw=+0.042 g_sm=+0.070 acc=1 | LR→0.121948 PERT→0.120012 (scale=0.04)
# [meta] cb#045 loss=0.875151 step=0.0859 g_raw=+0.042 g_sm=+0.059 acc=1 | LR→0.122193 PERT→0.120013 (scale=0.04)
# [meta] cb#050 loss=0.862097 step=0.01319 g_raw=+0.011 g_sm=+0.053 acc=1 | LR→0.122439 PERT→0.120015 (scale=0.04)
# [client 4 | unfold 2] LR 0.121213->0.122439, PERT 0.120007->0.120015 | g_raw_mean=+0.047, g_sm_mean=+0.067
# [meta] cb#055 loss=0.856857 step=0.06914 g_raw=+0.032 g_sm=+0.046 acc=1 | LR→0.122686 PERT→0.120016 (scale=0.04)
# [meta] cb#060 loss=0.855398 step=0.008382 g_raw=+0.005 g_sm=+0.038 acc=1 | LR→0.122932 PERT→0.120017 (scale=0.04)
# [meta] cb#065 loss=0.854705 step=0.02233 g_raw=+0.015 g_sm=+0.031 acc=1 | LR→0.123179 PERT→0.120018 (scale=0.04)
# [meta] cb#070 loss=0.853311 step=0.007285 g_raw=+0.002 g_sm=+0.026 acc=1 | LR→0.123426 PERT→0.120018 (scale=0.04)
# [meta] cb#075 loss=0.853058 step=0.007469 g_raw=+0.004 g_sm=+0.021 acc=1 | LR→0.123674 PERT→0.120019 (scale=0.04)
# [client 4 | unfold 3] LR 0.122439->0.123674, PERT 0.120015->0.120019 | g_raw_mean=+0.010, g_sm_mean=+0.034
# [meta] cb#080 loss=0.849603 step=0.01678 g_raw=+0.010 g_sm=+0.020 acc=1 | LR→0.123922 PERT→0.120019 (scale=0.04)
# [meta] cb#085 loss=0.848011 step=0.03051 g_raw=+0.012 g_sm=+0.018 acc=1 | LR→0.124171 PERT→0.120020 (scale=0.04)
# [meta] cb#090 loss=0.844057 step=0.05412 g_raw=+0.028 g_sm=+0.018 acc=1 | LR→0.124420 PERT→0.120020 (scale=0.04)
# [meta] cb#095 loss=0.842120 step=0.01128 g_raw=-0.000 g_sm=+0.017 acc=1 | LR→0.124669 PERT→0.120021 (scale=0.04)
# [meta] cb#100 loss=0.840711 step=0.002645 g_raw=+0.002 g_sm=+0.015 acc=1 | LR→0.124919 PERT→0.120021 (scale=0.04)
# [client 4 | unfold 4] LR 0.123674->0.124919, PERT 0.120019->0.120021 | g_raw_mean=+0.013, g_sm_mean=+0.018
# [meta] cb#105 loss=0.836942 step=0.005534 g_raw=+0.001 g_sm=+0.015 acc=1 | LR→0.125170 PERT→0.120021 (scale=0.04)
# [meta] cb#110 loss=0.835036 step=0.02503 g_raw=+0.012 g_sm=+0.015 acc=1 | LR→0.125421 PERT→0.120022 (scale=0.04)
# [meta] cb#115 loss=0.834150 step=0.01044 g_raw=+0.005 g_sm=+0.012 acc=1 | LR→0.125672 PERT→0.120022 (scale=0.04)
# [meta] cb#120 loss=0.833614 step=0.00655 g_raw=+0.003 g_sm=+0.011 acc=1 | LR→0.125924 PERT→0.120022 (scale=0.04)
# [meta] cb#125 loss=0.832363 step=0.004642 g_raw=+0.002 g_sm=+0.010 acc=1 | LR→0.126176 PERT→0.120023 (scale=0.04)
# [client 4 | unfold 5] LR 0.124919->0.126176, PERT 0.120021->0.120023 | g_raw_mean=+0.009, g_sm_mean=+0.013
#
# [Round 0] Validation per client
#       client      val_loss      test_acc      lr_final    pert_final
#            1      1.061379      0.551840      0.126177      0.120023
#            3      1.065875      0.533317      0.126179      0.120025
#            2      1.141389      0.563146      0.126189      0.120035
#            0      1.176293      0.529468      0.126174      0.120020
#            4      1.208895      0.557854      0.126176      0.120023
# → [Round 0] action=init_from_best, best_client=1, best_val=1.061379
# Training Progress:  10%|█         | 1/10 [10:02<1:30:19, 602.17s/it]
# [Round   0] acc_g=0.552 (μ=0.547, σ=0.013, FG=0.030) | t=533.584s, val=1.061 | TEL β=NA, Fid μ=NA, σ=NA, p50=NA, p90=NA | Lat μ=NA, σ=NA, p90=NA | Inst μ=NA, σ=NA | Δ per-dim=NA, ||Δ||₂=NA, max|Δ|=NA | noise=med, shots=256
# [Round 0] ↓=3B ↑=15B | (Σ↓=3B, Σ↑=15B)
# [Round 1] Agg=best | Uplink=quantum | Downlink=quantum
# [meta] cb#005 loss=1.513963 step=0.1091 g_raw=+0.045 g_sm=+0.045 acc=1 | LR→0.123334 PERT→0.120011 (scale=0.04)
# [meta] cb#010 loss=1.257957 step=0.2978 g_raw=+0.098 g_sm=+0.066 acc=1 | LR→0.123582 PERT→0.120012 (scale=0.04)
# [meta] cb#015 loss=1.103656 step=0.3496 g_raw=+0.203 g_sm=+0.075 acc=1 | LR→0.123831 PERT→0.120014 (scale=0.04)
# [meta] cb#020 loss=1.091807 step=0.07797 g_raw=+0.036 g_sm=+0.065 acc=1 | LR→0.124081 PERT→0.120016 (scale=0.04)
# [meta] cb#025 loss=1.001712 step=0.0275 g_raw=+0.011 g_sm=+0.069 acc=1 | LR→0.124331 PERT→0.120017 (scale=0.04)
# [client 0 | unfold 1] LR 0.123087->0.124331, PERT 0.120010->0.120017 | g_raw_mean=+0.110, g_sm_mean=+0.058
# [meta] cb#030 loss=0.980058 step=0.1311 g_raw=+0.068 g_sm=+0.062 acc=1 | LR→0.124582 PERT→0.120019 (scale=0.04)
# [meta] cb#035 loss=0.968515 step=0.02919 g_raw=+0.021 g_sm=+0.055 acc=1 | LR→0.124833 PERT→0.120020 (scale=0.04)
# [meta] cb#040 loss=0.958696 step=0.04664 g_raw=+0.026 g_sm=+0.049 acc=1 | LR→0.125084 PERT→0.120021 (scale=0.04)
# [meta] cb#045 loss=0.954463 step=0.006005 g_raw=-0.007 g_sm=+0.041 acc=1 | LR→0.125335 PERT→0.120022 (scale=0.04)
# [meta] cb#050 loss=0.945064 step=0.03581 g_raw=+0.023 g_sm=+0.037 acc=1 | LR→0.125587 PERT→0.120023 (scale=0.04)
# [client 0 | unfold 2] LR 0.124331->0.125587, PERT 0.120017->0.120023 | g_raw_mean=+0.027, g_sm_mean=+0.051
# [meta] cb#055 loss=0.931420 step=0.114 g_raw=+0.058 g_sm=+0.036 acc=1 | LR→0.125840 PERT→0.120024 (scale=0.04)
# [meta] cb#060 loss=0.923111 step=0.0265 g_raw=+0.006 g_sm=+0.033 acc=1 | LR→0.126092 PERT→0.120025 (scale=0.04)
# [meta] cb#065 loss=0.911613 step=0.1409 g_raw=+0.056 g_sm=+0.032 acc=1 | LR→0.126346 PERT→0.120026 (scale=0.04)
# [meta] cb#070 loss=0.900930 step=0.05025 g_raw=+0.026 g_sm=+0.031 acc=1 | LR→0.126599 PERT→0.120027 (scale=0.04)
# [meta] cb#075 loss=0.886021 step=0.05017 g_raw=+0.015 g_sm=+0.032 acc=1 | LR→0.126854 PERT→0.120027 (scale=0.04)
# [client 0 | unfold 3] LR 0.125587->0.126854, PERT 0.120023->0.120027 | g_raw_mean=+0.029, g_sm_mean=+0.033
# [meta] cb#080 loss=0.880097 step=0.03104 g_raw=+0.006 g_sm=+0.030 acc=1 | LR→0.127108 PERT→0.120028 (scale=0.04)
# [meta] cb#085 loss=0.870054 step=0.1153 g_raw=+0.046 g_sm=+0.028 acc=1 | LR→0.127364 PERT→0.120029 (scale=0.04)
# [meta] cb#090 loss=0.860503 step=0.07618 g_raw=+0.044 g_sm=+0.028 acc=1 | LR→0.127619 PERT→0.120029 (scale=0.04)
# [meta] cb#095 loss=0.854899 step=0.01819 g_raw=+0.006 g_sm=+0.026 acc=1 | LR→0.127875 PERT→0.120030 (scale=0.04)
# [meta] cb#100 loss=0.851246 step=0.02831 g_raw=+0.017 g_sm=+0.024 acc=1 | LR→0.128132 PERT→0.120031 (scale=0.04)
# [client 0 | unfold 4] LR 0.126854->0.128132, PERT 0.120027->0.120031 | g_raw_mean=+0.021, g_sm_mean=+0.028
# [meta] cb#105 loss=0.849703 step=0.002814 g_raw=+0.002 g_sm=+0.020 acc=1 | LR→0.128389 PERT→0.120031 (scale=0.04)
# [meta] cb#110 loss=0.846715 step=0.0001017 g_raw=-0.003 g_sm=+0.019 acc=1 | LR→0.128647 PERT→0.120032 (scale=0.04)
# [meta] cb#115 loss=0.843861 step=0.03544 g_raw=+0.022 g_sm=+0.018 acc=1 | LR→0.128905 PERT→0.120032 (scale=0.04)
# [meta] cb#120 loss=0.836928 step=0.03077 g_raw=+0.013 g_sm=+0.018 acc=1 | LR→0.129163 PERT→0.120032 (scale=0.04)
# [meta] cb#125 loss=0.835002 step=0.004915 g_raw=-0.000 g_sm=+0.016 acc=1 | LR→0.129422 PERT→0.120033 (scale=0.04)
# [client 0 | unfold 5] LR 0.128132->0.129422, PERT 0.120031->0.120033 | g_raw_mean=+0.013, g_sm_mean=+0.019
# [meta] cb#005 loss=1.413269 step=0.0555 g_raw=+0.017 g_sm=+0.020 acc=1 | LR→0.123335 PERT→0.120012 (scale=0.04)
# [meta] cb#010 loss=1.267531 step=0.06178 g_raw=+0.028 g_sm=+0.040 acc=1 | LR→0.123583 PERT→0.120013 (scale=0.04)
# [meta] cb#015 loss=1.121292 step=0.1666 g_raw=+0.102 g_sm=+0.053 acc=1 | LR→0.123831 PERT→0.120014 (scale=0.04)
# [meta] cb#020 loss=1.087886 step=0.06296 g_raw=+0.030 g_sm=+0.053 acc=1 | LR→0.124081 PERT→0.120015 (scale=0.04)
# [meta] cb#025 loss=1.043145 step=0.1316 g_raw=+0.065 g_sm=+0.055 acc=1 | LR→0.124330 PERT→0.120016 (scale=0.04)
# [client 1 | unfold 1] LR 0.123089->0.124330, PERT 0.120012->0.120016 | g_raw_mean=+0.080, g_sm_mean=+0.039
# [meta] cb#030 loss=0.948754 step=0.05524 g_raw=+0.028 g_sm=+0.063 acc=1 | LR→0.124581 PERT→0.120018 (scale=0.04)
# [meta] cb#035 loss=0.720143 step=0.2707 g_raw=+0.162 g_sm=+0.081 acc=1 | LR→0.124832 PERT→0.120020 (scale=0.04)
# [meta] cb#040 loss=0.598875 step=0.2846 g_raw=+0.176 g_sm=+0.087 acc=1 | LR→0.125084 PERT→0.120022 (scale=0.04)
# [meta] cb#045 loss=0.527265 step=0.03401 g_raw=+0.021 g_sm=+0.083 acc=1 | LR→0.125337 PERT→0.120024 (scale=0.04)
# [meta] cb#050 loss=0.474169 step=0.2096 g_raw=+0.114 g_sm=+0.078 acc=1 | LR→0.125589 PERT→0.120025 (scale=0.04)
# [client 1 | unfold 2] LR 0.124330->0.125589, PERT 0.120016->0.120025 | g_raw_mean=+0.094, g_sm_mean=+0.076
# [meta] cb#055 loss=0.418508 step=0.02949 g_raw=+0.013 g_sm=+0.075 acc=1 | LR→0.125843 PERT→0.120027 (scale=0.04)
# [meta] cb#060 loss=0.409087 step=0.04702 g_raw=+0.023 g_sm=+0.064 acc=1 | LR→0.126097 PERT→0.120029 (scale=0.04)
# [meta] cb#065 loss=0.373749 step=0.03445 g_raw=+0.018 g_sm=+0.061 acc=1 | LR→0.126351 PERT→0.120030 (scale=0.04)
# [meta] cb#070 loss=0.371832 step=0.03317 g_raw=+0.016 g_sm=+0.049 acc=1 | LR→0.126605 PERT→0.120032 (scale=0.04)
# [meta] cb#075 loss=0.364170 step=0.01855 g_raw=+0.006 g_sm=+0.042 acc=1 | LR→0.126859 PERT→0.120033 (scale=0.04)
# [client 1 | unfold 3] LR 0.125589->0.126859, PERT 0.120025->0.120033 | g_raw_mean=+0.034, g_sm_mean=+0.061
# [meta] cb#080 loss=0.360704 step=0.03872 g_raw=+0.018 g_sm=+0.036 acc=1 | LR→0.127114 PERT→0.120034 (scale=0.04)
# [meta] cb#085 loss=0.356493 step=0.07669 g_raw=+0.042 g_sm=+0.031 acc=1 | LR→0.127370 PERT→0.120035 (scale=0.04)
# [meta] cb#090 loss=0.352003 step=0.001346 g_raw=+0.004 g_sm=+0.028 acc=1 | LR→0.127625 PERT→0.120035 (scale=0.04)
# [meta] cb#095 loss=0.349258 step=0.01519 g_raw=+0.002 g_sm=+0.024 acc=1 | LR→0.127882 PERT→0.120036 (scale=0.04)
# [meta] cb#100 loss=0.347218 step=0.02501 g_raw=+0.012 g_sm=+0.022 acc=1 | LR→0.128138 PERT→0.120036 (scale=0.04)
# [client 1 | unfold 4] LR 0.126859->0.128138, PERT 0.120033->0.120036 | g_raw_mean=+0.014, g_sm_mean=+0.030
# [meta] cb#105 loss=0.344124 step=0.02312 g_raw=+0.009 g_sm=+0.020 acc=1 | LR→0.128395 PERT→0.120037 (scale=0.04)
# [meta] cb#110 loss=0.342546 step=0.01436 g_raw=+0.002 g_sm=+0.018 acc=1 | LR→0.128653 PERT→0.120037 (scale=0.04)
# [meta] cb#115 loss=0.335499 step=0.01146 g_raw=+0.006 g_sm=+0.019 acc=1 | LR→0.128911 PERT→0.120038 (scale=0.04)
# [meta] cb#120 loss=0.335231 step=0.02183 g_raw=+0.012 g_sm=+0.015 acc=1 | LR→0.129169 PERT→0.120038 (scale=0.04)
# [meta] cb#125 loss=0.333824 step=0.02635 g_raw=+0.013 g_sm=+0.014 acc=1 | LR→0.129428 PERT→0.120039 (scale=0.04)
# [client 1 | unfold 5] LR 0.128138->0.129428, PERT 0.120036->0.120039 | g_raw_mean=+0.012, g_sm_mean=+0.018
# [meta] cb#005 loss=1.506166 step=0.2438 g_raw=+0.154 g_sm=+0.051 acc=1 | LR→0.123342 PERT→0.120018 (scale=0.04)
# [meta] cb#010 loss=1.314210 step=0.03661 g_raw=+0.023 g_sm=+0.068 acc=1 | LR→0.123590 PERT→0.120020 (scale=0.04)
# [meta] cb#015 loss=1.160745 step=0.275 g_raw=+0.163 g_sm=+0.079 acc=1 | LR→0.123840 PERT→0.120022 (scale=0.04)
# [meta] cb#020 loss=1.138018 step=0.1703 g_raw=+0.063 g_sm=+0.071 acc=1 | LR→0.124089 PERT→0.120023 (scale=0.04)
# [meta] cb#025 loss=1.103123 step=0.03132 g_raw=+0.016 g_sm=+0.067 acc=1 | LR→0.124339 PERT→0.120025 (scale=0.04)
# [client 2 | unfold 1] LR 0.123095->0.124339, PERT 0.120017->0.120025 | g_raw_mean=+0.113, g_sm_mean=+0.062
# [meta] cb#030 loss=1.091184 step=0.02664 g_raw=+0.013 g_sm=+0.058 acc=1 | LR→0.124590 PERT→0.120026 (scale=0.04)
# [meta] cb#035 loss=1.075178 step=0.1693 g_raw=+0.078 g_sm=+0.051 acc=1 | LR→0.124841 PERT→0.120028 (scale=0.04)
# [meta] cb#040 loss=1.056771 step=0.08681 g_raw=+0.044 g_sm=+0.049 acc=1 | LR→0.125092 PERT→0.120029 (scale=0.04)
# [meta] cb#045 loss=1.036277 step=0.06822 g_raw=+0.032 g_sm=+0.047 acc=1 | LR→0.125343 PERT→0.120030 (scale=0.04)
# [meta] cb#050 loss=1.021392 step=0.07533 g_raw=+0.047 g_sm=+0.043 acc=1 | LR→0.125596 PERT→0.120031 (scale=0.04)
# [client 2 | unfold 2] LR 0.124339->0.125596, PERT 0.120025->0.120031 | g_raw_mean=+0.033, g_sm_mean=+0.051
# [meta] cb#055 loss=1.007937 step=0.08674 g_raw=+0.056 g_sm=+0.041 acc=1 | LR→0.125848 PERT→0.120032 (scale=0.04)
# [meta] cb#060 loss=0.997307 step=0.002739 g_raw=-0.001 g_sm=+0.036 acc=1 | LR→0.126101 PERT→0.120033 (scale=0.04)
# [meta] cb#065 loss=0.981430 step=0.07328 g_raw=+0.036 g_sm=+0.036 acc=1 | LR→0.126354 PERT→0.120034 (scale=0.04)
# [meta] cb#070 loss=0.942369 step=0.1104 g_raw=+0.049 g_sm=+0.041 acc=1 | LR→0.126608 PERT→0.120035 (scale=0.04)
# [meta] cb#075 loss=0.934175 step=0.07164 g_raw=+0.039 g_sm=+0.037 acc=1 | LR→0.126863 PERT→0.120036 (scale=0.04)
# [client 2 | unfold 3] LR 0.125596->0.126863, PERT 0.120031->0.120036 | g_raw_mean=+0.034, g_sm_mean=+0.039
# [meta] cb#080 loss=0.926958 step=0.008468 g_raw=+0.007 g_sm=+0.033 acc=1 | LR→0.127118 PERT→0.120037 (scale=0.04)
# [meta] cb#085 loss=0.893727 step=0.1703 g_raw=+0.102 g_sm=+0.037 acc=1 | LR→0.127373 PERT→0.120037 (scale=0.04)
# [meta] cb#090 loss=0.881122 step=0.1347 g_raw=+0.077 g_sm=+0.035 acc=1 | LR→0.127629 PERT→0.120038 (scale=0.04)
# [meta] cb#095 loss=0.853465 step=0.1201 g_raw=+0.067 g_sm=+0.036 acc=1 | LR→0.127885 PERT→0.120039 (scale=0.04)
# [meta] cb#100 loss=0.835356 step=0.00291 g_raw=+0.002 g_sm=+0.035 acc=1 | LR→0.128142 PERT→0.120040 (scale=0.04)
# [client 2 | unfold 4] LR 0.126863->0.128142, PERT 0.120036->0.120040 | g_raw_mean=+0.033, g_sm_mean=+0.035
# [meta] cb#105 loss=0.833823 step=0.03591 g_raw=+0.022 g_sm=+0.029 acc=1 | LR→0.128399 PERT→0.120041 (scale=0.04)
# [meta] cb#110 loss=0.826402 step=0.05302 g_raw=+0.022 g_sm=+0.028 acc=1 | LR→0.128657 PERT→0.120041 (scale=0.04)
# [meta] cb#115 loss=0.814606 step=0.01909 g_raw=+0.013 g_sm=+0.026 acc=1 | LR→0.128916 PERT→0.120042 (scale=0.04)
# [meta] cb#120 loss=0.811034 step=0.006633 g_raw=-0.002 g_sm=+0.023 acc=1 | LR→0.129174 PERT→0.120043 (scale=0.04)
# [meta] cb#125 loss=0.807664 step=0.03471 g_raw=+0.022 g_sm=+0.022 acc=1 | LR→0.129433 PERT→0.120043 (scale=0.04)
# [client 2 | unfold 5] LR 0.128142->0.129433, PERT 0.120040->0.120043 | g_raw_mean=+0.017, g_sm_mean=+0.026
# [meta] cb#005 loss=1.370698 step=0.1968 g_raw=+0.138 g_sm=+0.028 acc=1 | LR→0.123336 PERT→0.120013 (scale=0.04)
# [meta] cb#010 loss=1.185704 step=0.4793 g_raw=+0.223 g_sm=+0.045 acc=1 | LR→0.123584 PERT→0.120014 (scale=0.04)
# [meta] cb#015 loss=1.141137 step=0.15 g_raw=+0.066 g_sm=+0.048 acc=1 | LR→0.123833 PERT→0.120015 (scale=0.04)
# [meta] cb#020 loss=1.092050 step=0.1233 g_raw=+0.079 g_sm=+0.052 acc=1 | LR→0.124082 PERT→0.120016 (scale=0.04)
# [meta] cb#025 loss=1.056097 step=0.2032 g_raw=+0.107 g_sm=+0.052 acc=1 | LR→0.124332 PERT→0.120017 (scale=0.04)
# [client 3 | unfold 1] LR 0.123090->0.124332, PERT 0.120013->0.120017 | g_raw_mean=+0.080, g_sm_mean=+0.040
# [meta] cb#030 loss=0.949524 step=0.005494 g_raw=-0.000 g_sm=+0.059 acc=1 | LR→0.124582 PERT→0.120019 (scale=0.04)
# [meta] cb#035 loss=0.915244 step=0.06666 g_raw=+0.032 g_sm=+0.058 acc=1 | LR→0.124833 PERT→0.120020 (scale=0.04)
# [meta] cb#040 loss=0.864259 step=0.03359 g_raw=+0.011 g_sm=+0.057 acc=1 | LR→0.125084 PERT→0.120022 (scale=0.04)
# [meta] cb#045 loss=0.784573 step=0.1661 g_raw=+0.070 g_sm=+0.061 acc=1 | LR→0.125336 PERT→0.120023 (scale=0.04)
# [meta] cb#050 loss=0.721097 step=0.1056 g_raw=+0.054 g_sm=+0.065 acc=1 | LR→0.125589 PERT→0.120025 (scale=0.04)
# [client 3 | unfold 2] LR 0.124332->0.125589, PERT 0.120017->0.120025 | g_raw_mean=+0.070, g_sm_mean=+0.060
# [meta] cb#055 loss=0.592887 step=0.3526 g_raw=+0.177 g_sm=+0.074 acc=1 | LR→0.125842 PERT→0.120026 (scale=0.04)
# [meta] cb#060 loss=0.538563 step=0.1302 g_raw=+0.066 g_sm=+0.073 acc=1 | LR→0.126096 PERT→0.120028 (scale=0.04)
# [meta] cb#065 loss=0.524313 step=0.02628 g_raw=+0.008 g_sm=+0.064 acc=1 | LR→0.126350 PERT→0.120030 (scale=0.04)
# [meta] cb#070 loss=0.482931 step=0.1571 g_raw=+0.078 g_sm=+0.062 acc=1 | LR→0.126604 PERT→0.120031 (scale=0.04)
# [meta] cb#075 loss=0.476135 step=0.06471 g_raw=+0.032 g_sm=+0.053 acc=1 | LR→0.126859 PERT→0.120033 (scale=0.04)
# [client 3 | unfold 3] LR 0.125589->0.126859, PERT 0.120025->0.120033 | g_raw_mean=+0.057, g_sm_mean=+0.066
# [meta] cb#080 loss=0.459953 step=0.01172 g_raw=+0.004 g_sm=+0.047 acc=1 | LR→0.127115 PERT→0.120034 (scale=0.04)
# [meta] cb#085 loss=0.456899 step=0.002132 g_raw=+0.004 g_sm=+0.039 acc=1 | LR→0.127370 PERT→0.120035 (scale=0.04)
# [meta] cb#090 loss=0.451606 step=0.04165 g_raw=+0.019 g_sm=+0.035 acc=1 | LR→0.127626 PERT→0.120036 (scale=0.04)
# [meta] cb#095 loss=0.449056 step=0.01991 g_raw=+0.014 g_sm=+0.030 acc=1 | LR→0.127882 PERT→0.120036 (scale=0.04)
# [meta] cb#100 loss=0.443872 step=0.009451 g_raw=+0.005 g_sm=+0.027 acc=1 | LR→0.128139 PERT→0.120037 (scale=0.04)
# [client 3 | unfold 4] LR 0.126859->0.128139, PERT 0.120033->0.120037 | g_raw_mean=+0.018, g_sm_mean=+0.038
# [meta] cb#105 loss=0.439840 step=0.002237 g_raw=+0.001 g_sm=+0.024 acc=1 | LR→0.128396 PERT→0.120038 (scale=0.04)
# [meta] cb#110 loss=0.437320 step=0.02752 g_raw=+0.012 g_sm=+0.022 acc=1 | LR→0.128654 PERT→0.120038 (scale=0.04)
# [meta] cb#115 loss=0.432042 step=0.01936 g_raw=+0.010 g_sm=+0.021 acc=1 | LR→0.128912 PERT→0.120039 (scale=0.04)
# [meta] cb#120 loss=0.429566 step=0.03816 g_raw=+0.013 g_sm=+0.019 acc=1 | LR→0.129171 PERT→0.120039 (scale=0.04)
# [meta] cb#125 loss=0.423991 step=0.04361 g_raw=+0.025 g_sm=+0.020 acc=1 | LR→0.129430 PERT→0.120040 (scale=0.04)
# [client 3 | unfold 5] LR 0.128139->0.129430, PERT 0.120037->0.120040 | g_raw_mean=+0.016, g_sm_mean=+0.022
# [meta] cb#005 loss=1.898752 step=0.1194 g_raw=+0.088 g_sm=+0.039 acc=1 | LR→0.123335 PERT→0.120012 (scale=0.04)
# [meta] cb#010 loss=1.230107 step=0.2142 g_raw=+0.108 g_sm=+0.074 acc=1 | LR→0.123584 PERT→0.120013 (scale=0.04)
# [meta] cb#015 loss=1.162388 step=0.1754 g_raw=+0.106 g_sm=+0.077 acc=1 | LR→0.123833 PERT→0.120015 (scale=0.04)
# [meta] cb#020 loss=1.015540 step=0.04854 g_raw=+0.020 g_sm=+0.076 acc=1 | LR→0.124083 PERT→0.120017 (scale=0.04)
# [meta] cb#025 loss=0.927974 step=0.03784 g_raw=+0.015 g_sm=+0.077 acc=1 | LR→0.124333 PERT→0.120019 (scale=0.04)
# [client 4 | unfold 1] LR 0.123088->0.124333, PERT 0.120011->0.120019 | g_raw_mean=+0.122, g_sm_mean=+0.064
# [meta] cb#030 loss=0.888889 step=0.02908 g_raw=+0.014 g_sm=+0.070 acc=1 | LR→0.124584 PERT→0.120021 (scale=0.04)
# [meta] cb#035 loss=0.876620 step=0.01703 g_raw=+0.006 g_sm=+0.060 acc=1 | LR→0.124835 PERT→0.120022 (scale=0.04)
# [meta] cb#040 loss=0.821423 step=0.06626 g_raw=+0.033 g_sm=+0.061 acc=1 | LR→0.125086 PERT→0.120024 (scale=0.04)
# [meta] cb#045 loss=0.792791 step=0.082 g_raw=+0.040 g_sm=+0.058 acc=1 | LR→0.125338 PERT→0.120025 (scale=0.04)
# [meta] cb#050 loss=0.773261 step=0.04241 g_raw=+0.016 g_sm=+0.053 acc=1 | LR→0.125591 PERT→0.120026 (scale=0.04)
# [client 4 | unfold 2] LR 0.124333->0.125591, PERT 0.120019->0.120026 | g_raw_mean=+0.044, g_sm_mean=+0.063
# [meta] cb#055 loss=0.744583 step=0.03968 g_raw=+0.010 g_sm=+0.051 acc=1 | LR→0.125843 PERT→0.120028 (scale=0.04)
# [meta] cb#060 loss=0.741132 step=0.01638 g_raw=+0.009 g_sm=+0.043 acc=1 | LR→0.126096 PERT→0.120029 (scale=0.04)
# [meta] cb#065 loss=0.736515 step=0.01828 g_raw=+0.013 g_sm=+0.038 acc=1 | LR→0.126350 PERT→0.120030 (scale=0.04)
# [meta] cb#070 loss=0.727010 step=0.06976 g_raw=+0.038 g_sm=+0.035 acc=1 | LR→0.126604 PERT→0.120031 (scale=0.04)
# [meta] cb#075 loss=0.725103 step=0.01599 g_raw=+0.007 g_sm=+0.030 acc=1 | LR→0.126858 PERT→0.120031 (scale=0.04)
# [client 4 | unfold 3] LR 0.125591->0.126858, PERT 0.120026->0.120031 | g_raw_mean=+0.024, g_sm_mean=+0.042
# [meta] cb#080 loss=0.723803 step=0.001634 g_raw=-0.002 g_sm=+0.025 acc=1 | LR→0.127113 PERT→0.120032 (scale=0.04)
# [meta] cb#085 loss=0.722166 step=0.02736 g_raw=+0.010 g_sm=+0.022 acc=1 | LR→0.127368 PERT→0.120033 (scale=0.04)
# [meta] cb#090 loss=0.720729 step=0.01457 g_raw=+0.007 g_sm=+0.019 acc=1 | LR→0.127623 PERT→0.120033 (scale=0.04)
# [meta] cb#095 loss=0.720316 step=0.008173 g_raw=+0.006 g_sm=+0.016 acc=1 | LR→0.127879 PERT→0.120034 (scale=0.04)
# [meta] cb#100 loss=0.720154 step=0.01142 g_raw=+0.002 g_sm=+0.013 acc=1 | LR→0.128136 PERT→0.120034 (scale=0.04)
# [client 4 | unfold 4] LR 0.126858->0.128136, PERT 0.120031->0.120034 | g_raw_mean=+0.008, g_sm_mean=+0.020
# [meta] cb#105 loss=0.719821 step=0.0228 g_raw=+0.003 g_sm=+0.011 acc=1 | LR→0.128392 PERT→0.120034 (scale=0.04)
# [meta] cb#110 loss=0.717212 step=0.005328 g_raw=-0.001 g_sm=+0.011 acc=1 | LR→0.128650 PERT→0.120034 (scale=0.04)
# [meta] cb#115 loss=0.716890 step=0.001627 g_raw=+0.001 g_sm=+0.010 acc=1 | LR→0.128908 PERT→0.120035 (scale=0.04)
# [meta] cb#120 loss=0.714808 step=0.03127 g_raw=+0.015 g_sm=+0.010 acc=1 | LR→0.129166 PERT→0.120035 (scale=0.04)
# [meta] cb#125 loss=0.714596 step=0.01383 g_raw=+0.001 g_sm=+0.009 acc=1 | LR→0.129425 PERT→0.120035 (scale=0.04)
# [client 4 | unfold 5] LR 0.128136->0.129425, PERT 0.120034->0.120035 | g_raw_mean=+0.008, g_sm_mean=+0.011
#
# [Round 1] Validation per client
#       client      val_loss      test_acc      lr_final    pert_final
#            1      1.069184      0.565312      0.129428      0.120039
#            3      1.073616      0.569642      0.129430      0.120040
#            2      1.113009      0.599711      0.129433      0.120043
#            0      1.138719      0.509261      0.129422      0.120033
#            4      1.194212      0.535242      0.129425      0.120035
# → [Round 1] best_client=1, best_val=1.069184, prev_global_val=1.061379, improve=-0.007805, action=hold (τ=0.1)
# Training Progress:  20%|██        | 2/10 [19:31<1:17:43, 582.95s/it]
# [Round   1] acc_g=0.506 (μ=0.556, σ=0.031, FG=0.068) | t=500.486s, val=1.148 | TEL β=NA, Fid μ=NA, σ=NA, p50=NA, p90=NA | Lat μ=NA, σ=NA, p90=NA | Inst μ=NA, σ=NA | Δ per-dim=NA, ||Δ||₂=NA, max|Δ|=NA | noise=med, shots=256
# [Round 1] ↓=3B ↑=15B | (Σ↓=6B, Σ↑=30B)
# [Round 2] Agg=best | Uplink=quantum | Downlink=quantum
# [meta] cb#005 loss=1.261894 step=0.1755 g_raw=+0.101 g_sm=+0.041 acc=1 | LR→0.124961 PERT→0.120017 (scale=0.04)
# [meta] cb#010 loss=1.203623 step=0.1574 g_raw=+0.085 g_sm=+0.046 acc=1 | LR→0.125213 PERT→0.120018 (scale=0.04)
# [meta] cb#015 loss=1.150164 step=0.2138 g_raw=+0.122 g_sm=+0.049 acc=1 | LR→0.125465 PERT→0.120019 (scale=0.04)
# [meta] cb#020 loss=1.117768 step=0.03559 g_raw=+0.025 g_sm=+0.048 acc=1 | LR→0.125717 PERT→0.120020 (scale=0.04)
# [meta] cb#025 loss=1.102165 step=0.002973 g_raw=-0.001 g_sm=+0.043 acc=1 | LR→0.125970 PERT→0.120021 (scale=0.04)
# [client 0 | unfold 1] LR 0.124711->0.125970, PERT 0.120016->0.120021 | g_raw_mean=+0.075, g_sm_mean=+0.042
# [meta] cb#030 loss=1.047126 step=0.05283 g_raw=+0.025 g_sm=+0.049 acc=1 | LR→0.126223 PERT→0.120023 (scale=0.04)
# [meta] cb#035 loss=1.007820 step=0.1815 g_raw=+0.111 g_sm=+0.050 acc=1 | LR→0.126477 PERT→0.120024 (scale=0.04)
# [meta] cb#040 loss=0.968231 step=0.0811 g_raw=+0.034 g_sm=+0.051 acc=1 | LR→0.126732 PERT→0.120025 (scale=0.04)
# [meta] cb#045 loss=0.943877 step=0.02078 g_raw=+0.006 g_sm=+0.048 acc=1 | LR→0.126987 PERT→0.120026 (scale=0.04)
# [meta] cb#050 loss=0.928711 step=0.08613 g_raw=+0.052 g_sm=+0.045 acc=1 | LR→0.127242 PERT→0.120027 (scale=0.04)
# [client 0 | unfold 2] LR 0.125970->0.127242, PERT 0.120021->0.120027 | g_raw_mean=+0.051, g_sm_mean=+0.049
# [meta] cb#055 loss=0.894963 step=0.06413 g_raw=+0.038 g_sm=+0.047 acc=1 | LR→0.127498 PERT→0.120028 (scale=0.04)
# [meta] cb#060 loss=0.879635 step=0.05892 g_raw=+0.023 g_sm=+0.044 acc=1 | LR→0.127754 PERT→0.120030 (scale=0.04)
# [meta] cb#065 loss=0.853042 step=0.009916 g_raw=+0.000 g_sm=+0.044 acc=1 | LR→0.128011 PERT→0.120031 (scale=0.04)
# [meta] cb#070 loss=0.832046 step=0.1027 g_raw=+0.069 g_sm=+0.044 acc=1 | LR→0.128269 PERT→0.120032 (scale=0.04)
# [meta] cb#075 loss=0.823569 step=0.1176 g_raw=+0.007 g_sm=+0.038 acc=1 | LR→0.128526 PERT→0.120033 (scale=0.04)
# [client 0 | unfold 3] LR 0.127242->0.128526, PERT 0.120027->0.120033 | g_raw_mean=+0.039, g_sm_mean=+0.044
# [meta] cb#080 loss=0.818878 step=0.09124 g_raw=+0.031 g_sm=+0.033 acc=1 | LR→0.128785 PERT→0.120033 (scale=0.04)
# [meta] cb#085 loss=0.807054 step=0.105 g_raw=+0.061 g_sm=+0.033 acc=1 | LR→0.129043 PERT→0.120034 (scale=0.04)
# [meta] cb#090 loss=0.757051 step=0.08472 g_raw=+0.032 g_sm=+0.041 acc=1 | LR→0.129303 PERT→0.120035 (scale=0.04)
# [meta] cb#095 loss=0.727014 step=0.1951 g_raw=+0.092 g_sm=+0.042 acc=1 | LR→0.129563 PERT→0.120036 (scale=0.04)
# [meta] cb#100 loss=0.722016 step=0.09871 g_raw=+0.042 g_sm=+0.036 acc=1 | LR→0.129823 PERT→0.120037 (scale=0.04)
# [client 0 | unfold 4] LR 0.128526->0.129823, PERT 0.120033->0.120037 | g_raw_mean=+0.035, g_sm_mean=+0.036
# [meta] cb#105 loss=0.708669 step=0.1159 g_raw=+0.053 g_sm=+0.035 acc=1 | LR→0.130084 PERT→0.120038 (scale=0.04)
# [meta] cb#110 loss=0.686774 step=0.04704 g_raw=+0.022 g_sm=+0.036 acc=1 | LR→0.130345 PERT→0.120039 (scale=0.04)
# [meta] cb#115 loss=0.684304 step=0.01748 g_raw=+0.007 g_sm=+0.030 acc=1 | LR→0.130607 PERT→0.120039 (scale=0.04)
# [meta] cb#120 loss=0.676666 step=0.08882 g_raw=+0.042 g_sm=+0.029 acc=1 | LR→0.130869 PERT→0.120040 (scale=0.04)
# [meta] cb#125 loss=0.672993 step=0.07662 g_raw=+0.041 g_sm=+0.026 acc=1 | LR→0.131132 PERT→0.120041 (scale=0.04)
# [client 0 | unfold 5] LR 0.129823->0.131132, PERT 0.120037->0.120041 | g_raw_mean=+0.024, g_sm_mean=+0.032
# [meta] cb#005 loss=1.108570 step=1.189 g_raw=+0.500 g_sm=+0.054 acc=1 | LR→0.124964 PERT→0.120020 (scale=0.04)
# [meta] cb#010 loss=1.077664 step=0.08577 g_raw=+0.043 g_sm=+0.052 acc=1 | LR→0.125216 PERT→0.120021 (scale=0.04)
# [meta] cb#015 loss=0.966276 step=0.09474 g_raw=+0.036 g_sm=+0.056 acc=1 | LR→0.125468 PERT→0.120022 (scale=0.04)
# [meta] cb#020 loss=0.952523 step=0.09081 g_raw=+0.058 g_sm=+0.050 acc=1 | LR→0.125721 PERT→0.120024 (scale=0.04)
# [meta] cb#025 loss=0.738084 step=0.1248 g_raw=+0.069 g_sm=+0.069 acc=1 | LR→0.125974 PERT→0.120025 (scale=0.04)
# [client 1 | unfold 1] LR 0.124714->0.125974, PERT 0.120019->0.120025 | g_raw_mean=+0.103, g_sm_mean=+0.050
# [meta] cb#030 loss=0.718165 step=0.2135 g_raw=+0.081 g_sm=+0.059 acc=1 | LR→0.126228 PERT→0.120027 (scale=0.04)
# [meta] cb#035 loss=0.636714 step=0.08835 g_raw=+0.046 g_sm=+0.063 acc=1 | LR→0.126482 PERT→0.120028 (scale=0.04)
# [meta] cb#040 loss=0.598691 step=0.05193 g_raw=+0.026 g_sm=+0.058 acc=1 | LR→0.126737 PERT→0.120030 (scale=0.04)
# [meta] cb#045 loss=0.525188 step=0.1688 g_raw=+0.079 g_sm=+0.058 acc=1 | LR→0.126992 PERT→0.120031 (scale=0.04)
# [meta] cb#050 loss=0.507066 step=0.09847 g_raw=+0.030 g_sm=+0.052 acc=1 | LR→0.127247 PERT→0.120032 (scale=0.04)
# [client 1 | unfold 2] LR 0.125974->0.127247, PERT 0.120025->0.120032 | g_raw_mean=+0.046, g_sm_mean=+0.059
# [meta] cb#055 loss=0.491547 step=0.03883 g_raw=+0.010 g_sm=+0.046 acc=1 | LR→0.127504 PERT→0.120034 (scale=0.04)
# [meta] cb#060 loss=0.483347 step=0.05515 g_raw=+0.014 g_sm=+0.041 acc=1 | LR→0.127760 PERT→0.120035 (scale=0.04)
# [meta] cb#065 loss=0.475302 step=0.1026 g_raw=+0.045 g_sm=+0.037 acc=1 | LR→0.128017 PERT→0.120035 (scale=0.04)
# [meta] cb#070 loss=0.459019 step=0.1193 g_raw=+0.062 g_sm=+0.036 acc=1 | LR→0.128274 PERT→0.120036 (scale=0.04)
# [meta] cb#075 loss=0.453866 step=0.07177 g_raw=+0.036 g_sm=+0.032 acc=1 | LR→0.128531 PERT→0.120037 (scale=0.04)
# [client 1 | unfold 3] LR 0.127247->0.128531, PERT 0.120032->0.120037 | g_raw_mean=+0.024, g_sm_mean=+0.040
# [meta] cb#080 loss=0.450635 step=0.08412 g_raw=+0.029 g_sm=+0.027 acc=1 | LR→0.128789 PERT→0.120038 (scale=0.04)
# [meta] cb#085 loss=0.445131 step=0.03047 g_raw=+0.017 g_sm=+0.025 acc=1 | LR→0.129048 PERT→0.120038 (scale=0.04)
# [meta] cb#090 loss=0.443852 step=0.01232 g_raw=+0.002 g_sm=+0.020 acc=1 | LR→0.129307 PERT→0.120039 (scale=0.04)
# [meta] cb#095 loss=0.438776 step=0.04145 g_raw=+0.019 g_sm=+0.020 acc=1 | LR→0.129566 PERT→0.120039 (scale=0.04)
# [meta] cb#100 loss=0.436942 step=0.01522 g_raw=+0.006 g_sm=+0.017 acc=1 | LR→0.129826 PERT→0.120040 (scale=0.04)
# [client 1 | unfold 4] LR 0.128531->0.129826, PERT 0.120037->0.120040 | g_raw_mean=+0.012, g_sm_mean=+0.023
# [meta] cb#105 loss=0.433774 step=0.01821 g_raw=+0.009 g_sm=+0.017 acc=1 | LR→0.130087 PERT→0.120040 (scale=0.04)
# [meta] cb#110 loss=0.430717 step=0.0599 g_raw=+0.024 g_sm=+0.016 acc=1 | LR→0.130347 PERT→0.120041 (scale=0.04)
# [meta] cb#115 loss=0.429555 step=0.01262 g_raw=-0.001 g_sm=+0.014 acc=1 | LR→0.130609 PERT→0.120041 (scale=0.04)
# [meta] cb#120 loss=0.426885 step=0.001267 g_raw=-0.003 g_sm=+0.014 acc=1 | LR→0.130871 PERT→0.120041 (scale=0.04)
# [meta] cb#125 loss=0.426571 step=0.01502 g_raw=+0.001 g_sm=+0.012 acc=1 | LR→0.131133 PERT→0.120042 (scale=0.04)
# [client 1 | unfold 5] LR 0.129826->0.131133, PERT 0.120040->0.120042 | g_raw_mean=+0.011, g_sm_mean=+0.015
# [meta] cb#005 loss=1.663892 step=0.1873 g_raw=+0.105 g_sm=+0.019 acc=1 | LR→0.124967 PERT→0.120022 (scale=0.04)
# [meta] cb#010 loss=1.445702 step=0.4376 g_raw=+0.185 g_sm=+0.048 acc=1 | LR→0.125218 PERT→0.120023 (scale=0.04)
# [meta] cb#015 loss=1.377975 step=0.05328 g_raw=+0.030 g_sm=+0.055 acc=1 | LR→0.125470 PERT→0.120024 (scale=0.04)
# [meta] cb#020 loss=1.336048 step=0.2043 g_raw=+0.120 g_sm=+0.056 acc=1 | LR→0.125722 PERT→0.120025 (scale=0.04)
# [meta] cb#025 loss=1.266442 step=0.1902 g_raw=+0.098 g_sm=+0.059 acc=1 | LR→0.125975 PERT→0.120027 (scale=0.04)
# [client 2 | unfold 1] LR 0.124717->0.125975, PERT 0.120022->0.120027 | g_raw_mean=+0.087, g_sm_mean=+0.042
# [meta] cb#030 loss=1.237692 step=0.02947 g_raw=+0.023 g_sm=+0.057 acc=1 | LR→0.126229 PERT→0.120028 (scale=0.04)
# [meta] cb#035 loss=1.230077 step=0.02012 g_raw=+0.010 g_sm=+0.049 acc=1 | LR→0.126483 PERT→0.120029 (scale=0.04)
# [meta] cb#040 loss=1.204099 step=0.03941 g_raw=+0.019 g_sm=+0.048 acc=1 | LR→0.126738 PERT→0.120030 (scale=0.04)
# [meta] cb#045 loss=1.176047 step=0.05019 g_raw=+0.027 g_sm=+0.048 acc=1 | LR→0.126993 PERT→0.120032 (scale=0.04)
# [meta] cb#050 loss=1.137673 step=0.02721 g_raw=+0.022 g_sm=+0.049 acc=1 | LR→0.127248 PERT→0.120033 (scale=0.04)
# [client 2 | unfold 2] LR 0.125975->0.127248, PERT 0.120027->0.120033 | g_raw_mean=+0.043, g_sm_mean=+0.051
# [meta] cb#055 loss=1.123705 step=0.04349 g_raw=+0.019 g_sm=+0.046 acc=1 | LR→0.127504 PERT→0.120034 (scale=0.04)
# [meta] cb#060 loss=1.096837 step=0.03514 g_raw=+0.018 g_sm=+0.046 acc=1 | LR→0.127760 PERT→0.120035 (scale=0.04)
# [meta] cb#065 loss=1.090911 step=0.03795 g_raw=+0.010 g_sm=+0.040 acc=1 | LR→0.128017 PERT→0.120036 (scale=0.04)
# [meta] cb#070 loss=1.087135 step=0.01536 g_raw=+0.007 g_sm=+0.034 acc=1 | LR→0.128275 PERT→0.120037 (scale=0.04)
# [meta] cb#075 loss=1.081324 step=0.01408 g_raw=+0.007 g_sm=+0.031 acc=1 | LR→0.128532 PERT→0.120038 (scale=0.04)
# [client 2 | unfold 3] LR 0.127248->0.128532, PERT 0.120033->0.120038 | g_raw_mean=+0.028, g_sm_mean=+0.041
# [meta] cb#080 loss=1.073721 step=0.09922 g_raw=+0.063 g_sm=+0.029 acc=1 | LR→0.128790 PERT→0.120038 (scale=0.04)
# [meta] cb#085 loss=1.068554 step=0.04857 g_raw=+0.022 g_sm=+0.027 acc=1 | LR→0.129049 PERT→0.120039 (scale=0.04)
# [meta] cb#090 loss=1.062547 step=0.07517 g_raw=+0.044 g_sm=+0.026 acc=1 | LR→0.129308 PERT→0.120040 (scale=0.04)
# [meta] cb#095 loss=1.060717 step=0.0279 g_raw=+0.017 g_sm=+0.023 acc=1 | LR→0.129567 PERT→0.120040 (scale=0.04)
# [meta] cb#100 loss=1.050077 step=0.02618 g_raw=+0.019 g_sm=+0.023 acc=1 | LR→0.129827 PERT→0.120041 (scale=0.04)
# [client 2 | unfold 4] LR 0.128532->0.129827, PERT 0.120038->0.120041 | g_raw_mean=+0.020, g_sm_mean=+0.026
# [meta] cb#105 loss=1.045690 step=0.01625 g_raw=+0.010 g_sm=+0.022 acc=1 | LR→0.130088 PERT→0.120041 (scale=0.04)
# [meta] cb#110 loss=1.015767 step=0.15 g_raw=+0.092 g_sm=+0.028 acc=1 | LR→0.130349 PERT→0.120042 (scale=0.04)
# [meta] cb#115 loss=1.010397 step=0.03373 g_raw=+0.020 g_sm=+0.027 acc=1 | LR→0.130611 PERT→0.120043 (scale=0.04)
# [meta] cb#120 loss=1.000031 step=0.006948 g_raw=+0.002 g_sm=+0.025 acc=1 | LR→0.130873 PERT→0.120043 (scale=0.04)
# [meta] cb#125 loss=0.984127 step=0.04752 g_raw=+0.023 g_sm=+0.026 acc=1 | LR→0.131135 PERT→0.120044 (scale=0.04)
# [client 2 | unfold 5] LR 0.129827->0.131135, PERT 0.120041->0.120044 | g_raw_mean=+0.028, g_sm_mean=+0.025
# [meta] cb#005 loss=2.079576 step=0.5928 g_raw=+0.312 g_sm=+0.044 acc=1 | LR→0.124965 PERT→0.120020 (scale=0.04)
# [meta] cb#010 loss=1.308310 step=0.09985 g_raw=+0.058 g_sm=+0.073 acc=1 | LR→0.125217 PERT→0.120022 (scale=0.04)
# [meta] cb#015 loss=1.285147 step=0.1378 g_raw=+0.049 g_sm=+0.067 acc=1 | LR→0.125469 PERT→0.120024 (scale=0.04)
# [meta] cb#020 loss=1.241731 step=0.07295 g_raw=+0.038 g_sm=+0.066 acc=1 | LR→0.125722 PERT→0.120025 (scale=0.04)
# [meta] cb#025 loss=1.219646 step=0.0898 g_raw=+0.062 g_sm=+0.062 acc=1 | LR→0.125975 PERT→0.120027 (scale=0.04)
# [client 3 | unfold 1] LR 0.124715->0.125975, PERT 0.120020->0.120027 | g_raw_mean=+0.104, g_sm_mean=+0.057
# [meta] cb#030 loss=1.194479 step=0.04579 g_raw=+0.020 g_sm=+0.060 acc=1 | LR→0.126229 PERT→0.120028 (scale=0.04)
# [meta] cb#035 loss=1.168421 step=0.06042 g_raw=+0.037 g_sm=+0.056 acc=1 | LR→0.126483 PERT→0.120030 (scale=0.04)
# [meta] cb#040 loss=1.157956 step=0.123 g_raw=+0.068 g_sm=+0.049 acc=1 | LR→0.126738 PERT→0.120031 (scale=0.04)
# [meta] cb#045 loss=1.149182 step=0.08628 g_raw=+0.044 g_sm=+0.044 acc=1 | LR→0.126993 PERT→0.120032 (scale=0.04)
# [meta] cb#050 loss=1.140848 step=0.00702 g_raw=+0.008 g_sm=+0.040 acc=1 | LR→0.127248 PERT→0.120033 (scale=0.04)
# [client 3 | unfold 2] LR 0.125975->0.127248, PERT 0.120027->0.120033 | g_raw_mean=+0.034, g_sm_mean=+0.051
# [meta] cb#055 loss=1.077022 step=0.147 g_raw=+0.054 g_sm=+0.048 acc=1 | LR→0.127504 PERT→0.120034 (scale=0.04)
# [meta] cb#060 loss=1.061198 step=0.1222 g_raw=+0.066 g_sm=+0.044 acc=1 | LR→0.127760 PERT→0.120035 (scale=0.04)
# [meta] cb#065 loss=1.015711 step=0.05648 g_raw=+0.033 g_sm=+0.047 acc=1 | LR→0.128017 PERT→0.120036 (scale=0.04)
# [meta] cb#070 loss=0.973350 step=0.1804 g_raw=+0.106 g_sm=+0.049 acc=1 | LR→0.128275 PERT→0.120037 (scale=0.04)
# [meta] cb#075 loss=0.933330 step=0.02422 g_raw=+0.015 g_sm=+0.049 acc=1 | LR→0.128533 PERT→0.120039 (scale=0.04)
# [client 3 | unfold 3] LR 0.127248->0.128533, PERT 0.120033->0.120039 | g_raw_mean=+0.054, g_sm_mean=+0.047
# [meta] cb#080 loss=0.874518 step=0.2639 g_raw=+0.152 g_sm=+0.053 acc=1 | LR→0.128792 PERT→0.120040 (scale=0.04)
# ...
# [client 0 | unfold 3] LR 0.129059->0.130359, PERT 0.120034->0.120037 | g_raw_mean=+0.010, g_sm_mean=+0.024
# [meta] cb#080 loss=0.884012 step=0.02266 g_raw=+0.016 g_sm=+0.015 acc=1 | LR→0.130621 PERT→0.120037 (scale=0.04)
# [meta] cb#085 loss=0.882266 step=0.04985 g_raw=+0.029 g_sm=+0.014 acc=1 | LR→0.130883 PERT→0.120038 (scale=0.04)
# [meta] cb#090 loss=0.876375 step=0.07678 g_raw=+0.040 g_sm=+0.015 acc=1 | LR→0.131145 PERT→0.120038 (scale=0.04)
# [meta] cb#095 loss=0.874599 step=0.02091 g_raw=+0.023 g_sm=+0.015 acc=1 | LR→0.131408 PERT→0.120038 (scale=0.04)
# [meta] cb#100 loss=0.872344 step=0.01789 g_raw=+0.003 g_sm=+0.014 acc=1 | LR→0.131672 PERT→0.120039 (scale=0.04)
# [client 0 | unfold 4] LR 0.130359->0.131672, PERT 0.120037->0.120039 | g_raw_mean=+0.012, g_sm_mean=+0.014
# [meta] cb#105 loss=0.870962 step=0.009171 g_raw=+0.002 g_sm=+0.012 acc=1 | LR→0.131935 PERT→0.120039 (scale=0.04)
# [meta] cb#110 loss=0.870423 step=0.006156 g_raw=+0.007 g_sm=+0.010 acc=1 | LR→0.132200 PERT→0.120039 (scale=0.04)
# [meta] cb#115 loss=0.868407 step=0.02402 g_raw=+0.008 g_sm=+0.011 acc=1 | LR→0.132465 PERT→0.120039 (scale=0.04)
# [meta] cb#120 loss=0.867692 step=0.02503 g_raw=+0.013 g_sm=+0.010 acc=1 | LR→0.132730 PERT→0.120040 (scale=0.04)
# [meta] cb#125 loss=0.866381 step=0.01034 g_raw=+0.011 g_sm=+0.010 acc=1 | LR→0.132996 PERT→0.120040 (scale=0.04)
# [client 0 | unfold 5] LR 0.131672->0.132996, PERT 0.120039->0.120040 | g_raw_mean=+0.008, g_sm_mean=+0.011
# [meta] cb#005 loss=1.332995 step=0.7265 g_raw=+0.362 g_sm=+0.028 acc=1 | LR→0.126750 PERT→0.120027 (scale=0.04)
# [meta] cb#010 loss=1.203157 step=0.002725 g_raw=+0.010 g_sm=+0.036 acc=1 | LR→0.127004 PERT→0.120028 (scale=0.04)
# [meta] cb#015 loss=1.171016 step=0.1155 g_raw=+0.070 g_sm=+0.041 acc=1 | LR→0.127259 PERT→0.120029 (scale=0.04)
# [meta] cb#020 loss=1.135315 step=0.1672 g_raw=+0.077 g_sm=+0.044 acc=1 | LR→0.127515 PERT→0.120030 (scale=0.04)
# [meta] cb#025 loss=1.128978 step=0.07659 g_raw=+0.041 g_sm=+0.040 acc=1 | LR→0.127772 PERT→0.120031 (scale=0.04)
# [client 1 | unfold 1] LR 0.126496->0.127772, PERT 0.120027->0.120031 | g_raw_mean=+0.063, g_sm_mean=+0.033
# [meta] cb#030 loss=1.118343 step=0.03372 g_raw=+0.018 g_sm=+0.037 acc=1 | LR→0.128028 PERT→0.120032 (scale=0.04)
# [meta] cb#035 loss=1.101732 step=0.03831 g_raw=+0.030 g_sm=+0.035 acc=1 | LR→0.128286 PERT→0.120032 (scale=0.04)
# [meta] cb#040 loss=1.072861 step=0.01684 g_raw=+0.005 g_sm=+0.036 acc=1 | LR→0.128543 PERT→0.120033 (scale=0.04)
# [meta] cb#045 loss=1.050858 step=0.1085 g_raw=+0.043 g_sm=+0.037 acc=1 | LR→0.128802 PERT→0.120034 (scale=0.04)
# [meta] cb#050 loss=1.010130 step=0.07535 g_raw=+0.044 g_sm=+0.040 acc=1 | LR→0.129061 PERT→0.120035 (scale=0.04)
# [client 1 | unfold 2] LR 0.127772->0.129061, PERT 0.120031->0.120035 | g_raw_mean=+0.037, g_sm_mean=+0.037
# [meta] cb#055 loss=0.935759 step=0.1096 g_raw=+0.053 g_sm=+0.049 acc=1 | LR→0.129320 PERT→0.120036 (scale=0.04)
# [meta] cb#060 loss=0.895795 step=0.1279 g_raw=+0.060 g_sm=+0.052 acc=1 | LR→0.129580 PERT→0.120037 (scale=0.04)
# [meta] cb#065 loss=0.860834 step=0.1912 g_raw=+0.098 g_sm=+0.052 acc=1 | LR→0.129841 PERT→0.120039 (scale=0.04)
# [meta] cb#070 loss=0.824882 step=0.01967 g_raw=+0.003 g_sm=+0.048 acc=1 | LR→0.130102 PERT→0.120040 (scale=0.04)
# [meta] cb#075 loss=0.768811 step=0.1406 g_raw=+0.077 g_sm=+0.052 acc=1 | LR→0.130364 PERT→0.120041 (scale=0.04)
# [client 1 | unfold 3] LR 0.129061->0.130364, PERT 0.120035->0.120041 | g_raw_mean=+0.059, g_sm_mean=+0.050
# [meta] cb#080 loss=0.691947 step=0.3165 g_raw=+0.168 g_sm=+0.055 acc=1 | LR→0.130627 PERT→0.120042 (scale=0.04)
# [meta] cb#085 loss=0.653693 step=0.0164 g_raw=+0.006 g_sm=+0.053 acc=1 | LR→0.130889 PERT→0.120044 (scale=0.04)
# [meta] cb#090 loss=0.630078 step=0.0739 g_raw=+0.034 g_sm=+0.051 acc=1 | LR→0.131153 PERT→0.120045 (scale=0.04)
# [meta] cb#095 loss=0.620465 step=0.04911 g_raw=+0.021 g_sm=+0.045 acc=1 | LR→0.131417 PERT→0.120046 (scale=0.04)
# [meta] cb#100 loss=0.611391 step=0.07067 g_raw=+0.038 g_sm=+0.041 acc=1 | LR→0.131681 PERT→0.120047 (scale=0.04)
# [client 1 | unfold 4] LR 0.130364->0.131681, PERT 0.120041->0.120047 | g_raw_mean=+0.041, g_sm_mean=+0.049
# [meta] cb#105 loss=0.602879 step=0.05546 g_raw=+0.039 g_sm=+0.038 acc=1 | LR→0.131946 PERT→0.120048 (scale=0.04)
# [meta] cb#110 loss=0.597038 step=0.0338 g_raw=+0.018 g_sm=+0.034 acc=1 | LR→0.132211 PERT→0.120049 (scale=0.04)
# [meta] cb#115 loss=0.594558 step=0.06016 g_raw=+0.023 g_sm=+0.029 acc=1 | LR→0.132476 PERT→0.120050 (scale=0.04)
# [meta] cb#120 loss=0.593405 step=0.006004 g_raw=-0.001 g_sm=+0.024 acc=1 | LR→0.132742 PERT→0.120050 (scale=0.04)
# [meta] cb#125 loss=0.592272 step=0.006401 g_raw=-0.007 g_sm=+0.020 acc=1 | LR→0.133008 PERT→0.120051 (scale=0.04)
# [client 1 | unfold 5] LR 0.131681->0.133008, PERT 0.120047->0.120051 | g_raw_mean=+0.015, g_sm_mean=+0.031
# [meta] cb#005 loss=1.683823 step=0.4546 g_raw=+0.232 g_sm=+0.075 acc=1 | LR→0.126745 PERT→0.120023 (scale=0.04)
# [meta] cb#010 loss=1.307331 step=0.4793 g_raw=+0.262 g_sm=+0.103 acc=1 | LR→0.127001 PERT→0.120025 (scale=0.04)
# [meta] cb#015 loss=1.186910 step=0.3097 g_raw=+0.147 g_sm=+0.104 acc=1 | LR→0.127258 PERT→0.120028 (scale=0.04)
# [meta] cb#020 loss=1.141609 step=0.108 g_raw=+0.037 g_sm=+0.091 acc=1 | LR→0.127515 PERT→0.120030 (scale=0.04)
# [meta] cb#025 loss=1.128108 step=0.1125 g_raw=+0.055 g_sm=+0.079 acc=1 | LR→0.127773 PERT→0.120032 (scale=0.04)
# [client 2 | unfold 1] LR 0.126491->0.127773, PERT 0.120022->0.120032 | g_raw_mean=+0.142, g_sm_mean=+0.082
# [meta] cb#030 loss=1.122334 step=0.01488 g_raw=+0.012 g_sm=+0.066 acc=1 | LR→0.128030 PERT→0.120034 (scale=0.04)
# [meta] cb#035 loss=1.102497 step=0.09627 g_raw=+0.047 g_sm=+0.061 acc=1 | LR→0.128288 PERT→0.120035 (scale=0.04)
# [meta] cb#040 loss=1.096132 step=0.002468 g_raw=-0.001 g_sm=+0.052 acc=1 | LR→0.128546 PERT→0.120037 (scale=0.04)
# [meta] cb#045 loss=1.086963 step=0.01529 g_raw=+0.011 g_sm=+0.045 acc=1 | LR→0.128805 PERT→0.120038 (scale=0.04)
# [meta] cb#050 loss=1.072971 step=0.1439 g_raw=+0.048 g_sm=+0.041 acc=1 | LR→0.129064 PERT→0.120039 (scale=0.04)
# [client 2 | unfold 2] LR 0.127773->0.129064, PERT 0.120032->0.120039 | g_raw_mean=+0.027, g_sm_mean=+0.056
# [meta] cb#055 loss=1.034752 step=0.1522 g_raw=+0.043 g_sm=+0.044 acc=1 | LR→0.129324 PERT→0.120040 (scale=0.04)
# [meta] cb#060 loss=1.017009 step=0.09607 g_raw=+0.034 g_sm=+0.043 acc=1 | LR→0.129584 PERT→0.120041 (scale=0.04)
# [meta] cb#065 loss=0.999729 step=0.03355 g_raw=+0.046 g_sm=+0.042 acc=1 | LR→0.129844 PERT→0.120042 (scale=0.04)
# [meta] cb#070 loss=0.948408 step=0.08623 g_raw=+0.049 g_sm=+0.047 acc=1 | LR→0.130105 PERT→0.120043 (scale=0.04)
# [meta] cb#075 loss=0.923027 step=0.05886 g_raw=+0.026 g_sm=+0.045 acc=1 | LR→0.130367 PERT→0.120044 (scale=0.04)
# [client 2 | unfold 3] LR 0.129064->0.130367, PERT 0.120039->0.120044 | g_raw_mean=+0.047, g_sm_mean=+0.044
# [meta] cb#080 loss=0.893588 step=0.1607 g_raw=+0.085 g_sm=+0.045 acc=1 | LR→0.130629 PERT→0.120045 (scale=0.04)
# [meta] cb#085 loss=0.890023 step=0.06247 g_raw=+0.022 g_sm=+0.039 acc=1 | LR→0.130892 PERT→0.120046 (scale=0.04)
# [meta] cb#090 loss=0.875014 step=0.02092 g_raw=+0.009 g_sm=+0.035 acc=1 | LR→0.131155 PERT→0.120047 (scale=0.04)
# [meta] cb#095 loss=0.852285 step=0.1323 g_raw=+0.060 g_sm=+0.037 acc=1 | LR→0.131418 PERT→0.120048 (scale=0.04)
# [meta] cb#100 loss=0.840801 step=0.02553 g_raw=+0.027 g_sm=+0.036 acc=1 | LR→0.131682 PERT→0.120049 (scale=0.04)
# [client 2 | unfold 4] LR 0.130367->0.131682, PERT 0.120044->0.120049 | g_raw_mean=+0.033, g_sm_mean=+0.039
# [meta] cb#105 loss=0.827389 step=0.04718 g_raw=+0.019 g_sm=+0.035 acc=1 | LR→0.131947 PERT→0.120050 (scale=0.04)
# [meta] cb#110 loss=0.812373 step=0.1131 g_raw=+0.045 g_sm=+0.034 acc=1 | LR→0.132212 PERT→0.120050 (scale=0.04)
# [meta] cb#115 loss=0.778460 step=0.02404 g_raw=+0.011 g_sm=+0.036 acc=1 | LR→0.132478 PERT→0.120051 (scale=0.04)
# [meta] cb#120 loss=0.758981 step=0.1645 g_raw=+0.086 g_sm=+0.036 acc=1 | LR→0.132744 PERT→0.120052 (scale=0.04)
# [meta] cb#125 loss=0.741045 step=0.1438 g_raw=+0.083 g_sm=+0.036 acc=1 | LR→0.133010 PERT→0.120053 (scale=0.04)
# [client 2 | unfold 5] LR 0.131682->0.133010, PERT 0.120049->0.120053 | g_raw_mean=+0.035, g_sm_mean=+0.035
# [meta] cb#005 loss=1.466537 step=0.3645 g_raw=+0.149 g_sm=+0.028 acc=1 | LR→0.126747 PERT→0.120025 (scale=0.04)
# [meta] cb#010 loss=1.043821 step=0.1827 g_raw=+0.077 g_sm=+0.066 acc=1 | LR→0.127002 PERT→0.120026 (scale=0.04)
# [meta] cb#015 loss=0.890223 step=0.1393 g_raw=+0.056 g_sm=+0.070 acc=1 | LR→0.127258 PERT→0.120028 (scale=0.04)
# [meta] cb#020 loss=0.819468 step=0.00404 g_raw=+0.002 g_sm=+0.066 acc=1 | LR→0.127515 PERT→0.120029 (scale=0.04)
# [meta] cb#025 loss=0.734404 step=0.2639 g_raw=+0.130 g_sm=+0.070 acc=1 | LR→0.127772 PERT→0.120031 (scale=0.04)
# [client 3 | unfold 1] LR 0.126494->0.127772, PERT 0.120024->0.120031 | g_raw_mean=+0.108, g_sm_mean=+0.055
# [meta] cb#030 loss=0.662591 step=0.2226 g_raw=+0.104 g_sm=+0.069 acc=1 | LR→0.128029 PERT→0.120033 (scale=0.04)
# [meta] cb#035 loss=0.629577 step=0.1717 g_raw=+0.082 g_sm=+0.066 acc=1 | LR→0.128287 PERT→0.120034 (scale=0.04)
# [meta] cb#040 loss=0.611553 step=0.1035 g_raw=+0.056 g_sm=+0.059 acc=1 | LR→0.128546 PERT→0.120036 (scale=0.04)
# [meta] cb#045 loss=0.580596 step=0.1347 g_raw=+0.071 g_sm=+0.055 acc=1 | LR→0.128805 PERT→0.120037 (scale=0.04)
# [meta] cb#050 loss=0.569895 step=0.06757 g_raw=+0.032 g_sm=+0.049 acc=1 | LR→0.129064 PERT→0.120038 (scale=0.04)
# [client 3 | unfold 2] LR 0.127772->0.129064, PERT 0.120031->0.120038 | g_raw_mean=+0.045, g_sm_mean=+0.060
# [meta] cb#055 loss=0.565604 step=0.03142 g_raw=+0.015 g_sm=+0.042 acc=1 | LR→0.129323 PERT→0.120039 (scale=0.04)
# [meta] cb#060 loss=0.561655 step=0.06527 g_raw=+0.037 g_sm=+0.037 acc=1 | LR→0.129583 PERT→0.120040 (scale=0.04)
# [meta] cb#065 loss=0.561175 step=0.01209 g_raw=+0.009 g_sm=+0.030 acc=1 | LR→0.129844 PERT→0.120041 (scale=0.04)
# [meta] cb#070 loss=0.559657 step=0.03373 g_raw=+0.007 g_sm=+0.025 acc=1 | LR→0.130104 PERT→0.120042 (scale=0.04)
# [meta] cb#075 loss=0.554482 step=0.0404 g_raw=+0.016 g_sm=+0.023 acc=1 | LR→0.130365 PERT→0.120042 (scale=0.04)
# [client 3 | unfold 3] LR 0.129064->0.130365, PERT 0.120038->0.120042 | g_raw_mean=+0.013, g_sm_mean=+0.033
# [meta] cb#080 loss=0.554426 step=0.01262 g_raw=-0.001 g_sm=+0.018 acc=1 | LR→0.130627 PERT→0.120043 (scale=0.04)
# [meta] cb#085 loss=0.553556 step=0.009033 g_raw=+0.005 g_sm=+0.015 acc=1 | LR→0.130889 PERT→0.120043 (scale=0.04)
# [meta] cb#090 loss=0.552289 step=0.02668 g_raw=+0.019 g_sm=+0.014 acc=1 | LR→0.131151 PERT→0.120043 (scale=0.04)
# [meta] cb#095 loss=0.550944 step=0.02368 g_raw=+0.009 g_sm=+0.013 acc=1 | LR→0.131414 PERT→0.120044 (scale=0.04)
# [meta] cb#100 loss=0.550199 step=0.006309 g_raw=+0.006 g_sm=+0.012 acc=1 | LR→0.131677 PERT→0.120044 (scale=0.04)
# [client 3 | unfold 4] LR 0.130365->0.131677, PERT 0.120042->0.120044 | g_raw_mean=+0.007, g_sm_mean=+0.015
# [meta] cb#105 loss=0.548588 step=0.03489 g_raw=+0.008 g_sm=+0.011 acc=1 | LR→0.131941 PERT→0.120044 (scale=0.04)
# [meta] cb#110 loss=0.548064 step=0.02175 g_raw=+0.006 g_sm=+0.009 acc=1 | LR→0.132206 PERT→0.120045 (scale=0.04)
# [meta] cb#115 loss=0.546776 step=0.03137 g_raw=+0.014 g_sm=+0.009 acc=1 | LR→0.132471 PERT→0.120045 (scale=0.04)
# [meta] cb#120 loss=0.546502 step=0.003462 g_raw=-0.004 g_sm=+0.008 acc=1 | LR→0.132736 PERT→0.120045 (scale=0.04)
# [meta] cb#125 loss=0.545159 step=0.0469 g_raw=+0.017 g_sm=+0.008 acc=1 | LR→0.133002 PERT→0.120045 (scale=0.04)
# [client 3 | unfold 5] LR 0.131677->0.133002, PERT 0.120044->0.120045 | g_raw_mean=+0.006, g_sm_mean=+0.009
# [meta] cb#005 loss=2.005662 step=0.1185 g_raw=+0.102 g_sm=+0.022 acc=1 | LR→0.126743 PERT→0.120021 (scale=0.04)
# [meta] cb#010 loss=1.693135 step=0.07947 g_raw=+0.061 g_sm=+0.055 acc=1 | LR→0.126998 PERT→0.120022 (scale=0.04)
# [meta] cb#015 loss=1.507096 step=0.1498 g_raw=+0.075 g_sm=+0.074 acc=1 | LR→0.127254 PERT→0.120024 (scale=0.04)
# [meta] cb#020 loss=1.347535 step=0.131 g_raw=+0.058 g_sm=+0.081 acc=1 | LR→0.127511 PERT→0.120026 (scale=0.04)
# [meta] cb#025 loss=1.203131 step=0.1087 g_raw=+0.059 g_sm=+0.083 acc=1 | LR→0.127768 PERT→0.120028 (scale=0.04)
# [client 4 | unfold 1] LR 0.126490->0.127768, PERT 0.120021->0.120028 | g_raw_mean=+0.121, g_sm_mean=+0.058
# [meta] cb#030 loss=1.157130 step=0.05827 g_raw=+0.028 g_sm=+0.076 acc=1 | LR→0.128026 PERT→0.120030 (scale=0.04)
# [meta] cb#035 loss=1.148450 step=0.009147 g_raw=+0.010 g_sm=+0.065 acc=1 | LR→0.128284 PERT→0.120032 (scale=0.04)
# [meta] cb#040 loss=1.131985 step=0.09423 g_raw=+0.057 g_sm=+0.059 acc=1 | LR→0.128543 PERT→0.120033 (scale=0.04)
# [meta] cb#045 loss=1.066647 step=0.1777 g_raw=+0.091 g_sm=+0.062 acc=1 | LR→0.128802 PERT→0.120035 (scale=0.04)
# [meta] cb#050 loss=1.012858 step=0.2002 g_raw=+0.121 g_sm=+0.064 acc=1 | LR→0.129061 PERT→0.120036 (scale=0.04)
# [client 4 | unfold 2] LR 0.127768->0.129061, PERT 0.120028->0.120036 | g_raw_mean=+0.052, g_sm_mean=+0.066
# [meta] cb#055 loss=0.996601 step=0.0506 g_raw=+0.013 g_sm=+0.057 acc=1 | LR→0.129321 PERT→0.120037 (scale=0.04)
# [meta] cb#060 loss=0.990628 step=0.1121 g_raw=+0.036 g_sm=+0.048 acc=1 | LR→0.129581 PERT→0.120039 (scale=0.04)
# [meta] cb#065 loss=0.981160 step=0.04598 g_raw=+0.027 g_sm=+0.043 acc=1 | LR→0.129842 PERT→0.120040 (scale=0.04)
# [meta] cb#070 loss=0.972021 step=0.1143 g_raw=+0.042 g_sm=+0.039 acc=1 | LR→0.130103 PERT→0.120041 (scale=0.04)
# [meta] cb#075 loss=0.968151 step=0.03681 g_raw=+0.018 g_sm=+0.034 acc=1 | LR→0.130364 PERT→0.120042 (scale=0.04)
# [client 4 | unfold 3] LR 0.129061->0.130364, PERT 0.120036->0.120042 | g_raw_mean=+0.024, g_sm_mean=+0.046
# [meta] cb#080 loss=0.966544 step=0.0602 g_raw=+0.019 g_sm=+0.028 acc=1 | LR→0.130626 PERT→0.120042 (scale=0.04)
# [meta] cb#085 loss=0.964099 step=0.007037 g_raw=+0.001 g_sm=+0.024 acc=1 | LR→0.130888 PERT→0.120043 (scale=0.04)
# [meta] cb#090 loss=0.957380 step=0.05088 g_raw=+0.027 g_sm=+0.024 acc=1 | LR→0.131151 PERT→0.120044 (scale=0.04)
# [meta] cb#095 loss=0.957146 step=0.004389 g_raw=-0.004 g_sm=+0.019 acc=1 | LR→0.131414 PERT→0.120044 (scale=0.04)
# [meta] cb#100 loss=0.953232 step=0.05535 g_raw=+0.018 g_sm=+0.018 acc=1 | LR→0.131678 PERT→0.120044 (scale=0.04)
# [client 4 | unfold 4] LR 0.130364->0.131678, PERT 0.120042->0.120044 | g_raw_mean=+0.012, g_sm_mean=+0.024
# [meta] cb#105 loss=0.950901 step=0.01569 g_raw=+0.014 g_sm=+0.017 acc=1 | LR→0.131942 PERT→0.120045 (scale=0.04)
# [meta] cb#110 loss=0.949951 step=0.04372 g_raw=+0.019 g_sm=+0.015 acc=1 | LR→0.132206 PERT→0.120045 (scale=0.04)
# [meta] cb#115 loss=0.948918 step=0.009201 g_raw=-0.003 g_sm=+0.013 acc=1 | LR→0.132471 PERT→0.120046 (scale=0.04)
# [meta] cb#120 loss=0.944191 step=0.01804 g_raw=+0.015 g_sm=+0.014 acc=1 | LR→0.132737 PERT→0.120046 (scale=0.04)
# [meta] cb#125 loss=0.935387 step=0.05548 g_raw=+0.026 g_sm=+0.017 acc=1 | LR→0.133003 PERT→0.120046 (scale=0.04)
# [client 4 | unfold 5] LR 0.131678->0.133003, PERT 0.120044->0.120046 | g_raw_mean=+0.014, g_sm_mean=+0.015
#
# [Round 9] Validation per client
#       client      val_loss      test_acc      lr_final    pert_final
#            2      1.075436      0.620880      0.133010      0.120053
#            3      1.118225      0.524417      0.133002      0.120045
#            1      1.133107      0.520808      0.133008      0.120051
#            4      1.133110      0.552321      0.133003      0.120046
#            0      1.180276      0.528987      0.132996      0.120040
# → [Round 9] best_client=2, best_val=1.075436, prev_global_val=1.354015, improve=+0.278579, action=adopt+mix τ=0.5
# Training Progress: 100%|██████████| 10/10 [1:40:42<00:00, 604.21s/it]
# [Round   9] acc_g=0.568 (μ=0.549, σ=0.037, FG=0.071) | t=566.349s, val=1.117 | TEL β=NA, Fid μ=NA, σ=NA, p50=NA, p90=NA | Lat μ=NA, σ=NA, p90=NA | Inst μ=NA, σ=NA | Δ per-dim=NA, ||Δ||₂=NA, max|Δ|=NA | noise=med, shots=256
# [Round 9] ↓=3B ↑=15B | (Σ↓=30B, Σ↑=150B)
# Global accuracy per round: [0.5518402694250661, 0.5061342314168872, 0.3495309117151792, 0.4055809477988934, 0.49771469809959107, 0.4779889343276401, 0.43035843156122205, 0.3329324031753669, 0.42699061823430356, 0.5679576617753187]

# %% [markdown]
# run federated loop and plot

# %%
from training.loop import run_federated_training
from configs.base_config import use_teleportation as CFG_TEL, noise_preset, shots_used
from training.metrics import metrics_init, metrics_log_round, metrics_finalize, compute_auc,metrics_summarize
from viz.plots import plot_accuracy_curve, plot_val_loss, plot_time_per_round, plot_fidelity_vs_delta_acc, plot_beta_hist, plot_client_fairness_last_round
# Initialize metrics store once
metrics_store = metrics_init(
    log_path=os.path.join(drive_root, "teleport_metrics_Perturb_shrink.csv")
)

#new
from ml import optimizers as mlopt
from configs.base_config import drive_root
import os

mlopt.meta_trace_enable(
    path=os.path.join(drive_root, "meta_trace.csv"),  # or None to skip CSV
    every=5                                           # print every 5 callbacks
)

# examples/run_switch.py
from configs.base_config import *
from training.data_factory import build_clients_and_meta
from training.loop import run_federated_training
from training.metrics import metrics_init
import os, numpy as np

# 1) Build clients + meta from config
clients, test_sequences, test_labels, num_features = build_clients_and_meta(
    dataset_name=dataset_name,
    split_type=split_type,
    num_clients=num_clients,
    num_epochs=num_epochs,
    samples_per_epoch=samples_per_epoch,
    word_size=word_size,
    global_seed=global_seed,
    mnist_n_features=mnist_n_features,
    mnist_digit_a=mnist_digit_a,
    mnist_digit_b=mnist_digit_b,
    breast_pca_n_features=breast_pca_n_features,
    non_iid_ratio=non_iid_ratio,
    quantity_variation=quantity_variation,
    noniid_seed=noniid_seed,
)

# 2) Validation set (use test as val if you don’t have a separate split)
X_val, y_val = test_sequences, test_labels

# 3) Outputs
os.makedirs(drive_root, exist_ok=True)
best_client_csv_file = f"{drive_root}/best_client.csv"
global_csv_file      = f"{drive_root}/global_accuracies.csv"
local_csv_file       = f"{drive_root}/local_training.csv"
validation_csv_file  = f"{drive_root}/validation.csv"

metrics = metrics_init(log_path=os.path.join(drive_root, "round_metrics.csv"))

# 4) Train
global_acc, clients_train, clients_test, round_times, val_losses, info_last = run_federated_training(
    clients=clients,
    num_federated_layers=num_federated_layers,
    num_deep_unfolding_iterations=num_deep_unfolding_iterations,
    initial_learning_rate=initial_learning_rate,
    initial_perturbation=initial_perturbation,
    num_features=num_features,
    best_client_csv_file=best_client_csv_file,
    global_csv_file=global_csv_file,
    local_csv_file=local_csv_file,
    validation_csv_file=validation_csv_file,
    test_sequences=test_sequences, test_labels=test_labels,
    X_val=X_val,
    y_val=y_val,
    metrics=metrics,
    aggregation=aggregation,                  # "best" or "fedavg"
    select_upload=select_upload,              # "all" or "winner_only" (used for best)
    use_deep_unfolding=use_deep_unfolding,    # True/False
    uplink_mode=uplink_mode,                  # "classical_full" | "seeded_sparse" | "quantum"
    downlink_mode=downlink_mode,              # "classical_full" | "seeded" | "quantum"
    down_seed_base=down_seed_base,
    down_scale=down_scale,
    down_mask_ratio=down_mask_ratio,
    up_bits=up_bits,
    up_k_ratio=up_k_ratio,
    use_teleportation_backend=True,
    noise_preset=noise_preset,
    shots_used=shots_used,
    client_hparams_csv_file=os.path.join(drive_root, f"hparams_{dataset_name}_{split_type}.csv"),
)

print("Global accuracy per round:", global_acc)
# Out:
# Training Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# [Round 0] Agg=best | Uplink=quantum | Downlink=quantum
# [meta] cb#005 loss=1.714484 step=0.03312 g_raw=+0.030 g_sm=+0.050 acc=1 | LR→0.120241 PERT→0.120001 (scale=0.04)
# [meta] cb#010 loss=1.294770 step=0.04561 g_raw=+0.024 g_sm=+0.076 acc=1 | LR→0.120483 PERT→0.120002 (scale=0.04)
# [meta] cb#015 loss=1.067572 step=0.08225 g_raw=+0.043 g_sm=+0.085 acc=1 | LR→0.120727 PERT→0.120004 (scale=0.04)
# [meta] cb#020 loss=0.976399 step=0.07987 g_raw=+0.042 g_sm=+0.084 acc=1 | LR→0.120970 PERT→0.120006 (scale=0.04)
# [meta] cb#025 loss=0.911699 step=0.0853 g_raw=+0.035 g_sm=+0.079 acc=1 | LR→0.121215 PERT→0.120008 (scale=0.04)
# [client 0 | unfold 1] LR 0.120000->0.121215, PERT 0.120000->0.120008 | g_raw_mean=+0.131, g_sm_mean=+0.070
# [meta] cb#030 loss=0.886582 step=0.0691 g_raw=+0.034 g_sm=+0.071 acc=1 | LR→0.121459 PERT→0.120010 (scale=0.04)
# [meta] cb#035 loss=0.883209 step=0.006014 g_raw=+0.001 g_sm=+0.058 acc=1 | LR→0.121704 PERT→0.120012 (scale=0.04)
# [meta] cb#040 loss=0.880759 step=0.004201 g_raw=-0.001 g_sm=+0.048 acc=1 | LR→0.121949 PERT→0.120013 (scale=0.04)
# [meta] cb#045 loss=0.876868 step=0.006264 g_raw=+0.001 g_sm=+0.040 acc=1 | LR→0.122194 PERT→0.120014 (scale=0.04)
# [meta] cb#050 loss=0.875220 step=0.01561 g_raw=+0.008 g_sm=+0.033 acc=1 | LR→0.122439 PERT→0.120015 (scale=0.04)
# [client 0 | unfold 2] LR 0.121215->0.122439, PERT 0.120008->0.120015 | g_raw_mean=+0.019, g_sm_mean=+0.054
# [meta] cb#055 loss=0.874272 step=0.000525 g_raw=-0.001 g_sm=+0.027 acc=1 | LR→0.122685 PERT→0.120016 (scale=0.04)
# [meta] cb#060 loss=0.873499 step=0.01125 g_raw=+0.004 g_sm=+0.023 acc=1 | LR→0.122931 PERT→0.120016 (scale=0.04)
# [meta] cb#065 loss=0.873093 step=0.008399 g_raw=+0.004 g_sm=+0.018 acc=1 | LR→0.123178 PERT→0.120017 (scale=0.04)
# [meta] cb#070 loss=0.873122 step=0.00375 g_raw=+0.003 g_sm=+0.014 acc=1 | LR→0.123425 PERT→0.120017 (scale=0.04)
# [meta] cb#075 loss=0.872766 step=0.01531 g_raw=+0.004 g_sm=+0.012 acc=1 | LR→0.123672 PERT→0.120017 (scale=0.04)
# [client 0 | unfold 3] LR 0.122439->0.123672, PERT 0.120015->0.120017 | g_raw_mean=+0.004, g_sm_mean=+0.021
# [meta] cb#080 loss=0.872538 step=0.01423 g_raw=+0.007 g_sm=+0.010 acc=1 | LR→0.123920 PERT→0.120018 (scale=0.04)
# [meta] cb#085 loss=0.872337 step=0.005356 g_raw=+0.002 g_sm=+0.009 acc=1 | LR→0.124169 PERT→0.120018 (scale=0.04)
# [meta] cb#090 loss=0.871927 step=0.004868 g_raw=-0.000 g_sm=+0.008 acc=1 | LR→0.124417 PERT→0.120018 (scale=0.04)
# [meta] cb#095 loss=0.871370 step=0.002637 g_raw=+0.002 g_sm=+0.007 acc=1 | LR→0.124667 PERT→0.120018 (scale=0.04)
# [meta] cb#100 loss=0.870779 step=0.01109 g_raw=+0.008 g_sm=+0.007 acc=1 | LR→0.124916 PERT→0.120018 (scale=0.04)
# [client 0 | unfold 4] LR 0.123672->0.124916, PERT 0.120017->0.120018 | g_raw_mean=+0.005, g_sm_mean=+0.009
# [meta] cb#105 loss=0.870386 step=0.001244 g_raw=+0.003 g_sm=+0.007 acc=1 | LR→0.125167 PERT→0.120019 (scale=0.04)
# [meta] cb#110 loss=0.870110 step=0.01277 g_raw=+0.006 g_sm=+0.006 acc=1 | LR→0.125417 PERT→0.120019 (scale=0.04)
# [meta] cb#115 loss=0.869920 step=0.00721 g_raw=+0.003 g_sm=+0.006 acc=1 | LR→0.125669 PERT→0.120019 (scale=0.04)
# [meta] cb#120 loss=0.869775 step=0.01061 g_raw=+0.002 g_sm=+0.005 acc=1 | LR→0.125920 PERT→0.120019 (scale=0.04)
# [meta] cb#125 loss=0.869525 step=0.01488 g_raw=+0.006 g_sm=+0.004 acc=1 | LR→0.126173 PERT→0.120019 (scale=0.04)
# [client 0 | unfold 5] LR 0.124916->0.126173, PERT 0.120018->0.120019 | g_raw_mean=+0.004, g_sm_mean=+0.006
# [meta] cb#005 loss=1.141901 step=0.09415 g_raw=+0.049 g_sm=+0.023 acc=1 | LR→0.120241 PERT→0.120000 (scale=0.04)
# [meta] cb#010 loss=1.127254 step=0.1329 g_raw=+0.092 g_sm=+0.023 acc=1 | LR→0.120482 PERT→0.120001 (scale=0.04)
# [meta] cb#015 loss=1.085990 step=0.146 g_raw=+0.078 g_sm=+0.032 acc=1 | LR→0.120724 PERT→0.120001 (scale=0.04)
# [meta] cb#020 loss=1.059652 step=0.009833 g_raw=+0.012 g_sm=+0.035 acc=1 | LR→0.120966 PERT→0.120002 (scale=0.04)
# [meta] cb#025 loss=1.055989 step=0.04015 g_raw=+0.028 g_sm=+0.032 acc=1 | LR→0.121209 PERT→0.120003 (scale=0.04)
# Training Progress:   0%|          | 0/10 [01:42<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3665537953.py in <cell line: 0>()
#      56
#      57 # 4) Train
# ---> 58 global_acc, clients_train, clients_test, round_times, val_losses, info_last = run_federated_training(
#      59     clients=clients,
#      60     num_federated_layers=num_federated_layers,
#
# /content/drive/MyDrive/Teleportation/tduqfl_mnist/tDuQFL_Project/training/loop.py in run_federated_training(clients, num_federated_layers, num_deep_unfolding_iterations, initial_learning_rate, initial_perturbation, num_features, best_client_csv_file, global_csv_file, local_csv_file, validation_csv_file, test_sequences, test_labels, X_val, y_val, metrics, aggregation, select_upload, use_deep_unfolding, gamma, uplink_mode, downlink_mode, down_seed_base, down_scale, down_mask_ratio, up_bits, up_k_ratio, use_teleportation_backend, noise_preset, shots_used, client_hparams_csv_file)
#     297                 mlopt.seed_hparams(lr0, pert0)
#     298
# --> 299             model, train_score, test_score, _, lr_final, pert_final = train_qnn_model(
#     300                 current_data, client.test_data,
#     301                 num_deep_unfolding_iterations,
#
# /content/drive/MyDrive/Teleportation/tduqfl_mnist/tDuQFL_Project/training/loop.py in train_qnn_model(client_data, client_test_data, num_deep_unfolding_iterations, initial_learning_rate, initial_perturbation, num_features, csv_file, client_id, layer, use_deep_unfolding)
#     162         # compute accuracies using predict_proba (n,4)
#     163         p_tr = model.predict_proba(Xtr)
# --> 164         p_te = model.predict_proba(Xte)
#     165         train_acc = float((p_tr.argmax(axis=1) == ytr).mean())
#     166         test_acc  = float((p_te.argmax(axis=1) == yte).mean())
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/algorithms/classifiers/neural_network_classifier.py in predict_proba(self, X)
#     207
#     208         # Assumes an activation function is applied within the forward method
# --> 209         proba = self._neural_network.forward(X, self._fit_result.x)
#     210
#     211         return proba
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/neural_networks/neural_network.py in forward(self, input_data, weights)
#     227         input_, shape = self._validate_input(input_data)
#     228         weights_ = self._validate_weights(weights)
# --> 229         output_data = self._forward(input_, weights_)
#     230         return self._validate_forward_output(output_data, shape)
#     231
#
# /usr/local/lib/python3.12/dist-packages/qiskit_machine_learning/neural_networks/sampler_qnn.py in _forward(self, input_data, weights)
#     495             )
#     496         try:
# --> 497             results = job.result()
#     498         except Exception as exc:
#     499             raise QiskitMachineLearningError(f"Sampler job failed: {exc}") from exc
#
# /usr/local/lib/python3.12/dist-packages/qiskit/primitives/primitive_job.py in result(self)
#      49     def result(self) -> ResultT:
#      50         self._check_submitted()
# ---> 51         return self._future.result()
#      52
#      53     def status(self) -> JobStatus:
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:
